# %% [markdown]
# ## 1. Dataset Information

# %% [markdown]
# This dataset provides a balanced collection of images of benign and malignant skin moles, designed to support skin cancer diagnosis research and applications.
#
# ### Dataset Content
# - **Images**: The dataset includes **3,600 images** with equal representation of both benign and malignant moles.
#   - **Image Size**: All images are of resolution **224x224 pixels**.
#   - **Categories**:
#     - **Benign Moles**: 1,800 images
#     - **Malignant Moles**: 1,800 images
#
# ### Skin Cancer Types
#
# ####  **Benign Moles**
# Benign moles, also known as **nevi**, are non-cancerous skin growths that do not pose any immediate threat to health. They typically appear as small, brown, or tan spots on the skin. Although benign moles are usually harmless, it's important to monitor changes in size, color, or shape, as these changes could indicate the early development of skin cancer.
#
# ####  **Malignant Moles**
# Malignant moles, also referred to as **melanomas**, are cancerous skin growths that can be life-threatening if not detected early. Melanoma arises from melanocytes, the cells responsible for producing pigment in the skin. Malignant moles can vary in appearance, but common warning signs include asymmetry, irregular borders, multiple colors, and a diameter larger than a pencil eraser. Early detection and treatment are crucial for improving survival rates.
#
# ### Usage Rights
# The dataset is governed by the **ISIC-Archive rights**. For more details, please refer to the official [ISIC Archive](https://www.isic-archive.com/#!/topWithHeader/wideContentTop/main).

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## 2. Data Visualization

# %% [markdown]
# ### 2.1 Dataset Sample

# %%
import os
import random
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Define the path to your test directory
vis_dir = '/content/drive/MyDrive/Personal/Projects/CNN/train'

# Get the list of all subdirectories (classes)
classes = os.listdir(vis_dir)

# Initialize an empty list to store file paths
image_paths = []

# Loop through each class folder and collect a few image paths
for cls in classes:
    class_dir = os.path.join(vis_dir, cls)
    images = os.listdir(class_dir)
    for img in images:
        image_paths.append(os.path.join(class_dir, img))

# Randomly select 16 images from the test set
random_images = random.sample(image_paths, 16)

# Set up a 4x4 grid for plotting
fig, axes = plt.subplots(4, 4, figsize=(10, 10))

# Loop through the grid and add an image to each subplot
for i, ax in enumerate(axes.flat):
    img = mpimg.imread(random_images[i])
    ax.imshow(img)
    ax.axis('off')  # Hide axes

# Display the plot
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-secondary" style="font-size:14px; font-family:verdana; background-color:#d3d3d3; color:#555555;">
#     📌 The images have a size of 224 by 224, which is suitable for CNN models, so there is no need to resize them. However, we will include the resizing code later on in case you need it for a special dataset.
# </div>

# %% [markdown]
# ### 2.2 Training Data Distribution

# %%
# Get the list of all subdirectories (classes)
classes = os.listdir(vis_dir)

# Count the number of images in each class
image_count = {cls: len(os.listdir(os.path.join(vis_dir, cls))) for cls in classes}

# Create a bar plot
plt.figure(figsize=(12, 6))
plt.bar(image_count.keys(), image_count.values(), color='skyblue')
plt.xlabel('Class')
plt.ylabel('Number of Images')
plt.title('Number of Images per Class in the Training Data')
plt.xticks(rotation=90, ha='right')  # Rotate class names for better readability
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-secondary" style="font-size:14px; font-family:verdana; background-color:#d3d3d3; color:#555555;">
#     📌 As you can see, the dataset is balanced. There is a slight difference between the two classes, but it's not an extreme difference.
# </div>

# %% [markdown]
# ### 2.3 Test Data Distribution

# %%
test_vis_dir = '/content/drive/MyDrive/Personal/Projects/CNN/test'
# test_vis_dir = ''

# Get the list of all subdirectories (classes)
classes = os.listdir(test_vis_dir)

# Count the number of images in each class
image_count = {cls: len(os.listdir(os.path.join(test_vis_dir, cls))) for cls in classes}

# Create a bar plot
plt.figure(figsize=(12, 6))
plt.bar(image_count.keys(), image_count.values(), color='orange')
plt.xlabel('Class')
plt.ylabel('Number of Images')
plt.title('Number of Images per Class in the Test Data')
plt.xticks(rotation=90, ha='right')  # Rotate class names for better readability
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-secondary" style="font-size:14px; font-family:verdana; background-color:#d3d3d3; color:#555555;">
#     📌 The same applies to the test data, which means we can rely on accuracy as a metric to evaluate the model.
# </div>

# %% [markdown]
# ## 3. Resizing Images

# %% [markdown]
# ### 3.1 Resizing Images to 224x224 Pixels

# %% [markdown]
# <div class="alert alert-block alert-secondary" style="font-size:14px; font-family:verdana; background-color:#d3d3d3; color:#555555;">
#     ⚠️ This resizing step is absolutely not necessary for this dataset, as all the images are already 224 by 224 and we will be using this same size for our models. However, we chose to include this code in case you opt to use a different size, such as 64x64.
#
# </div>

# %%
import os
from PIL import Image

# Define paths
input_dirs = {
    'train': '/content/drive/MyDrive/Personal/Projects/CNN/train',
    'test': '/content/drive/MyDrive/Personal/Projects/CNN/test'
}
output_dir = './output'

# Create output directory and subdirectories if they don't exist
for subset in input_dirs.keys():
    subset_dir = os.path.join(output_dir, subset)
    if not os.path.exists(subset_dir):
        os.makedirs(subset_dir)

def resize_and_save_image(input_path, output_path, size=(224, 224)):
    try:
        with Image.open(input_path) as img:
            # Handle images with Transparency in Palette mode
            if img.mode == 'P':
                img = img.convert('RGBA')
            # Convert image to RGB if it has an alpha channel or is Palette based
            if img.mode in ('RGBA', 'LA') or (img.mode == 'P' and 'transparency' in img.info):
                img = img.convert('RGB')
            img = img.resize(size, Image.LANCZOS)
            img.save(output_path, format='JPEG')
    except Exception as e:
        print(f"Error processing {input_path}: {e}")

def process_directory(input_directory, output_directory):
    for root, dirs, files in os.walk(input_directory):
        # Create the corresponding directory structure in the output directory
        relative_path = os.path.relpath(root, input_directory)
        output_path = os.path.join(output_directory, relative_path)
        if not os.path.exists(output_path):
            os.makedirs(output_path)

        # Process each image file
        for file_name in files:
            if file_name.lower().endswith(('.png', '.jpg', '.jpeg')):
                input_file_path = os.path.join(root, file_name)
                output_file_path = os.path.join(output_path, file_name)
                resize_and_save_image(input_file_path, output_file_path)

# Process each directory separately
for subset, dir_path in input_dirs.items():
    process_directory(dir_path, os.path.join(output_dir, subset))

print("Resizing and saving images completed.")
# Out:
# Resizing and saving images completed.

# %% [markdown]
# <div class="alert alert-block alert-secondary" style="font-size:14px; font-family:verdana; background-color:#d3d3d3; color:#555555;">
#     📌 All the resized images are saved to the output folder.
# </div>

# %% [markdown]
# ## 4. Data Generators

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import warnings

# Ignore all warnings
warnings.filterwarnings("ignore")

# Define paths
train_dir = './output/train'
test_dir = './output/test'


# Create an instance of the ImageDataGenerator with data augmentation for the training set
train_datagen = ImageDataGenerator(
    rescale=1./255,
)
# Create an instance of the ImageDataGenerator for the test set (usually without augmentation)
test_datagen = ImageDataGenerator(rescale=1./255)

# Create the generators
train_generator = train_datagen.flow_from_directory(
    train_dir,
    seed= 777,
    target_size=(224, 224),  # Resize all images to 150x150 pixels
    batch_size=20,           # Number of images to yield per batch
    class_mode='binary' # Since we have only 2 classes
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    seed= 777,
    target_size=(224, 224),
    batch_size=20,
    class_mode='binary'
)
# Out:
# 2024-08-22 19:01:53.907181: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-22 19:01:53.907278: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-22 19:01:54.026601: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Found 2637 images belonging to 2 classes.
# Found 660 images belonging to 2 classes.

# %% [markdown]
# ## 5. Implementing Transfer Learning

# %%
from tensorflow.keras.applications import Xception, ResNet50, VGG16, InceptionV3, DenseNet121
from tensorflow.keras.applications import MobileNet, MobileNetV2, NASNetMobile, EfficientNetB0, EfficientNetB3, EfficientNetB4, ResNet101, ResNet152
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint

def create_model(base_model_class, input_shape=(224, 224, 3)):
    base_model = base_model_class(weights='imagenet', include_top=False, input_shape=input_shape)
    base_model.trainable = False

    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(1024, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.8)(x)
    x = Dense(512, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    predictions = Dense(1, activation='sigmoid')(x)

    model = Model(inputs=base_model.input, outputs=predictions)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
# List of models to try
models = [
    ('Xception', Xception),
    ('ResNet50', ResNet50),
    ('VGG16', VGG16),
    ('InceptionV3', InceptionV3),
    ('DenseNet121', DenseNet121),
    ('MobileNet', MobileNet),
    ('MobileNetV2', MobileNetV2),
    ('NASNetMobile', NASNetMobile),
    ('EfficientNetB0', EfficientNetB0),
    ('EfficientNetB3', EfficientNetB3),
    ('EfficientNetB4', EfficientNetB4),
    ('ResNet101', ResNet101),
    ('ResNet152', ResNet152),

]

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

best_model_name = None
best_val_accuracy = 0

for model_name, model_class in models:
    print(f"Training {model_name}...")

    model = create_model(model_class)

    # Define a ModelCheckpoint callback to save the best model
    checkpoint = ModelCheckpoint(f'{model_name}_best_model.keras', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

    # Train the model
    history = model.fit(
        train_generator,
        epochs=10,
        validation_data=test_generator,
        verbose=2,
        callbacks=[checkpoint]
    )

    # Evaluate the model on the validation set
    val_accuracy = max(history.history['val_accuracy'])

    # Save the best model based on validation accuracy
    if val_accuracy > best_val_accuracy:
        best_val_accuracy = val_accuracy
        best_model_name = model_name

    print(f"{model_name} validation accuracy: {val_accuracy}")

print(f"The best performing model is {best_model_name} with a validation accuracy of {best_val_accuracy}")
# Out:
# Training Xception...
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Epoch 1/10
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1724353348.209316      85 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1724353348.253942      85 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1724353367.020770      82 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Epoch 1: val_accuracy improved from -inf to 0.77727, saving model to Xception_best_model.keras
# 132/132 - 39s - 299ms/step - accuracy: 0.7057 - loss: 0.7507 - val_accuracy: 0.7773 - val_loss: 0.4504
# Epoch 2/10
#
# Epoch 2: val_accuracy improved from 0.77727 to 0.81515, saving model to Xception_best_model.keras
# 132/132 - 9s - 66ms/step - accuracy: 0.7562 - loss: 0.5865 - val_accuracy: 0.8152 - val_loss: 0.3908
# Epoch 3/10
#
# Epoch 3: val_accuracy did not improve from 0.81515
# 132/132 - 8s - 61ms/step - accuracy: 0.7755 - loss: 0.5085 - val_accuracy: 0.7970 - val_loss: 0.4121
# Epoch 4/10
#
# Epoch 4: val_accuracy improved from 0.81515 to 0.81818, saving model to Xception_best_model.keras
# 132/132 - 9s - 66ms/step - accuracy: 0.7884 - loss: 0.4574 - val_accuracy: 0.8182 - val_loss: 0.3746
# Epoch 5/10
#
# Epoch 5: val_accuracy improved from 0.81818 to 0.82273, saving model to Xception_best_model.keras
# 132/132 - 9s - 67ms/step - accuracy: 0.8028 - loss: 0.4185 - val_accuracy: 0.8227 - val_loss: 0.3653
# Epoch 6/10
#
# Epoch 6: val_accuracy improved from 0.82273 to 0.82576, saving model to Xception_best_model.keras
# 132/132 - 9s - 67ms/step - accuracy: 0.8146 - loss: 0.4125 - val_accuracy: 0.8258 - val_loss: 0.3726
# Epoch 7/10
#
# Epoch 7: val_accuracy did not improve from 0.82576
# 132/132 - 8s - 60ms/step - accuracy: 0.8203 - loss: 0.3977 - val_accuracy: 0.8258 - val_loss: 0.3740
# Epoch 8/10
#
# Epoch 8: val_accuracy did not improve from 0.82576
# 132/132 - 8s - 60ms/step - accuracy: 0.8244 - loss: 0.3874 - val_accuracy: 0.8258 - val_loss: 0.3539
# Epoch 9/10
#
# Epoch 9: val_accuracy did not improve from 0.82576
# 132/132 - 8s - 60ms/step - accuracy: 0.8354 - loss: 0.3702 - val_accuracy: 0.8242 - val_loss: 0.3565
# Epoch 10/10
#
# Epoch 10: val_accuracy did not improve from 0.82576
# 132/132 - 8s - 60ms/step - accuracy: 0.8320 - loss: 0.3644 - val_accuracy: 0.8242 - val_loss: 0.3641
# Xception validation accuracy: 0.8257575631141663
# Training ResNet50...
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Epoch 1/10
# W0000 00:00:1724353465.579263      83 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1724353482.293497      83 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Epoch 1: val_accuracy improved from -inf to 0.45455, saving model to ResNet50_best_model.keras
# 132/132 - 35s - 268ms/step - accuracy: 0.7292 - loss: 0.6824 - val_accuracy: 0.4545 - val_loss: 1.4403
# Epoch 2/10
#
# Epoch 2: val_accuracy improved from 0.45455 to 0.46970, saving model to ResNet50_best_model.keras
# 132/132 - 7s - 51ms/step - accuracy: 0.7490 - loss: 0.5648 - val_accuracy: 0.4697 - val_loss: 0.7147
# Epoch 3/10
#
# Epoch 3: val_accuracy improved from 0.46970 to 0.65606, saving model to ResNet50_best_model.keras
# 132/132 - 7s - 51ms/step - accuracy: 0.7691 - loss: 0.5153 - val_accuracy: 0.6561 - val_loss: 0.5625
# Epoch 4/10
#
# Epoch 4: val_accuracy improved from 0.65606 to 0.66364, saving model to ResNet50_best_model.keras
# 132/132 - 7s - 51ms/step - accuracy: 0.7873 - loss: 0.4825 - val_accuracy: 0.6636 - val_loss: 0.6329
# Epoch 5/10
#
# Epoch 5: val_accuracy did not improve from 0.66364
# 132/132 - 9s - 70ms/step - accuracy: 0.7823 - loss: 0.4666 - val_accuracy: 0.4561 - val_loss: 2.1655
# Epoch 6/10
#
# Epoch 6: val_accuracy improved from 0.66364 to 0.73485, saving model to ResNet50_best_model.keras
# 132/132 - 7s - 51ms/step - accuracy: 0.7933 - loss: 0.4420 - val_accuracy: 0.7348 - val_loss: 0.5545
# Epoch 7/10
#
# Epoch 7: val_accuracy did not improve from 0.73485
# 132/132 - 6s - 44ms/step - accuracy: 0.7926 - loss: 0.4452 - val_accuracy: 0.5955 - val_loss: 1.5225
# Epoch 8/10
#
# Epoch 8: val_accuracy did not improve from 0.73485
# 132/132 - 6s - 44ms/step - accuracy: 0.8043 - loss: 0.4232 - val_accuracy: 0.4545 - val_loss: 2.6259
# Epoch 9/10
#
# Epoch 9: val_accuracy did not improve from 0.73485
# 132/132 - 6s - 44ms/step - accuracy: 0.7983 - loss: 0.4308 - val_accuracy: 0.6045 - val_loss: 1.5656
# Epoch 10/10
#
# Epoch 10: val_accuracy did not improve from 0.73485
# 132/132 - 6s - 43ms/step - accuracy: 0.8138 - loss: 0.4143 - val_accuracy: 0.5773 - val_loss: 2.0664
# ResNet50 validation accuracy: 0.7348484992980957
# Training VGG16...
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Epoch 1/10
# 2024-08-22 19:05:50.638697: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 50176: 3.79983, expected 3.15789
# 2024-08-22 19:05:50.638759: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 50177: 5.13466, expected 4.49272
# 2024-08-22 19:05:50.638769: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 50178: 4.78155, expected 4.13961
# 2024-08-22 19:05:50.638777: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 50179: 4.88295, expected 4.24101
# 2024-08-22 19:05:50.638786: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 50180: 4.73279, expected 4.09085
# 2024-08-22 19:05:50.638794: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 50181: 4.69943, expected 4.05749
# 2024-08-22 19:05:50.638801: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 50182: 4.1975, expected 3.55556
# 2024-08-22 19:05:50.638823: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 50183: 4.73806, expected 4.09612
# 2024-08-22 19:05:50.638834: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 50184: 4.63452, expected 3.99258
# 2024-08-22 19:05:50.638844: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 50185: 4.5168, expected 3.87486
# 2024-08-22 19:05:50.667251: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[20,64,224,224]{3,2,1,0}, u8[0]{0}) custom-call(f32[20,3,224,224]{3,2,1,0}, f32[64,3,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-08-22 19:05:50.667301: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-08-22 19:05:50.667310: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-08-22 19:05:50.667317: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12040 (550.90.7)
# 2024-08-22 19:05:50.667324: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-08-22 19:05:50.667340: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-08-22 19:05:51.359182: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 50176: 3.79983, expected 3.15789
# 2024-08-22 19:05:51.359239: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 50177: 5.13466, expected 4.49272
# 2024-08-22 19:05:51.359248: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 50178: 4.78155, expected 4.13961
# 2024-08-22 19:05:51.359257: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 50179: 4.88295, expected 4.24101
# 2024-08-22 19:05:51.359265: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 50180: 4.73279, expected 4.09085
# 2024-08-22 19:05:51.359272: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 50181: 4.69943, expected 4.05749
# 2024-08-22 19:05:51.359280: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 50182: 4.1975, expected 3.55556
# 2024-08-22 19:05:51.359288: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 50183: 4.73806, expected 4.09612
# 2024-08-22 19:05:51.359296: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 50184: 4.63452, expected 3.99258
# 2024-08-22 19:05:51.359303: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 50185: 4.5168, expected 3.87486
# 2024-08-22 19:05:51.387388: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[20,64,224,224]{3,2,1,0}, u8[0]{0}) custom-call(f32[20,3,224,224]{3,2,1,0}, f32[64,3,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-08-22 19:05:51.387444: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-08-22 19:05:51.387453: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-08-22 19:05:51.387461: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12040 (550.90.7)
# 2024-08-22 19:05:51.387468: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-08-22 19:05:51.387485: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-08-22 19:06:05.858932: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 3.78784, expected 3.0263
# 2024-08-22 19:06:05.858998: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 1: 4.93362, expected 4.17208
# 2024-08-22 19:06:05.859011: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 2: 4.6423, expected 3.88076
# 2024-08-22 19:06:05.859022: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 3: 5.47141, expected 4.70987
# 2024-08-22 19:06:05.859032: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 4: 4.66224, expected 3.90069
# 2024-08-22 19:06:05.859046: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 5: 4.17686, expected 3.41531
# 2024-08-22 19:06:05.859063: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 6: 5.08184, expected 4.32029
# 2024-08-22 19:06:05.859073: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 7: 5.02696, expected 4.26542
# 2024-08-22 19:06:05.859084: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 8: 4.39626, expected 3.63472
# 2024-08-22 19:06:05.859094: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 9: 5.02789, expected 4.26634
# 2024-08-22 19:06:05.884644: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[17,64,224,224]{3,2,1,0}, u8[0]{0}) custom-call(f32[17,3,224,224]{3,2,1,0}, f32[64,3,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-08-22 19:06:05.884695: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-08-22 19:06:05.884708: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-08-22 19:06:05.884724: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12040 (550.90.7)
# 2024-08-22 19:06:05.884734: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-08-22 19:06:05.884755: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-08-22 19:06:06.428663: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 3.78784, expected 3.0263
# 2024-08-22 19:06:06.428728: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 1: 4.93362, expected 4.17208
# 2024-08-22 19:06:06.428742: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 2: 4.6423, expected 3.88076
# 2024-08-22 19:06:06.428753: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 3: 5.47141, expected 4.70987
# 2024-08-22 19:06:06.428763: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 4: 4.66224, expected 3.90069
# 2024-08-22 19:06:06.428776: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 5: 4.17686, expected 3.41531
# 2024-08-22 19:06:06.428794: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 6: 5.08184, expected 4.32029
# 2024-08-22 19:06:06.428819: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 7: 5.02696, expected 4.26542
# 2024-08-22 19:06:06.428833: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 8: 4.39626, expected 3.63472
# 2024-08-22 19:06:06.428843: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 9: 5.02789, expected 4.26634
# 2024-08-22 19:06:06.452881: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[17,64,224,224]{3,2,1,0}, u8[0]{0}) custom-call(f32[17,3,224,224]{3,2,1,0}, f32[64,3,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-08-22 19:06:06.452931: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-08-22 19:06:06.452943: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-08-22 19:06:06.452953: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12040 (550.90.7)
# 2024-08-22 19:06:06.452963: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-08-22 19:06:06.452988: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# Epoch 1: val_accuracy improved from -inf to 0.78939, saving model to VGG16_best_model.keras
# 132/132 - 39s - 294ms/step - accuracy: 0.7550 - loss: 0.6237 - val_accuracy: 0.7894 - val_loss: 0.4987
# Epoch 2/10
#
# Epoch 2: val_accuracy improved from 0.78939 to 0.80909, saving model to VGG16_best_model.keras
# 132/132 - 9s - 68ms/step - accuracy: 0.7766 - loss: 0.5483 - val_accuracy: 0.8091 - val_loss: 0.4101
# Epoch 3/10
#
# Epoch 3: val_accuracy did not improve from 0.80909
# 132/132 - 10s - 74ms/step - accuracy: 0.7823 - loss: 0.4713 - val_accuracy: 0.8076 - val_loss: 0.3936
# Epoch 4/10
#
# Epoch 4: val_accuracy did not improve from 0.80909
# 132/132 - 9s - 65ms/step - accuracy: 0.7801 - loss: 0.4428 - val_accuracy: 0.8000 - val_loss: 0.4003
# Epoch 5/10
#
# Epoch 5: val_accuracy did not improve from 0.80909
# 132/132 - 9s - 65ms/step - accuracy: 0.7941 - loss: 0.4254 - val_accuracy: 0.8061 - val_loss: 0.4163
# Epoch 6/10
#
# Epoch 6: val_accuracy improved from 0.80909 to 0.83333, saving model to VGG16_best_model.keras
# 132/132 - 9s - 69ms/step - accuracy: 0.8085 - loss: 0.3980 - val_accuracy: 0.8333 - val_loss: 0.4155
# Epoch 7/10
#
# Epoch 7: val_accuracy improved from 0.83333 to 0.84242, saving model to VGG16_best_model.keras
# 132/132 - 9s - 68ms/step - accuracy: 0.8146 - loss: 0.4040 - val_accuracy: 0.8424 - val_loss: 0.3876
# Epoch 8/10
#
# Epoch 8: val_accuracy did not improve from 0.84242
# 132/132 - 9s - 64ms/step - accuracy: 0.8142 - loss: 0.3843 - val_accuracy: 0.8348 - val_loss: 0.3671
# Epoch 9/10
#
# Epoch 9: val_accuracy did not improve from 0.84242
# 132/132 - 9s - 65ms/step - accuracy: 0.8195 - loss: 0.3952 - val_accuracy: 0.7712 - val_loss: 0.4184
# Epoch 10/10
#
# Epoch 10: val_accuracy did not improve from 0.84242
# 132/132 - 9s - 65ms/step - accuracy: 0.8074 - loss: 0.3855 - val_accuracy: 0.8379 - val_loss: 0.3584
# VGG16 validation accuracy: 0.842424213886261
# Training InceptionV3...
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Epoch 1/10
# W0000 00:00:1724353692.529262      82 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1724353716.680838      83 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Epoch 1: val_accuracy improved from -inf to 0.79394, saving model to InceptionV3_best_model.keras
# 132/132 - 50s - 375ms/step - accuracy: 0.7144 - loss: 0.7216 - val_accuracy: 0.7939 - val_loss: 0.4775
# Epoch 2/10
#
# Epoch 2: val_accuracy improved from 0.79394 to 0.82121, saving model to InceptionV3_best_model.keras
# 132/132 - 7s - 55ms/step - accuracy: 0.7490 - loss: 0.5946 - val_accuracy: 0.8212 - val_loss: 0.3935
# Epoch 3/10
#
# Epoch 3: val_accuracy did not improve from 0.82121
# 132/132 - 6s - 46ms/step - accuracy: 0.7903 - loss: 0.4805 - val_accuracy: 0.7985 - val_loss: 0.4134
# Epoch 4/10
#
# Epoch 4: val_accuracy did not improve from 0.82121
# 132/132 - 6s - 46ms/step - accuracy: 0.7967 - loss: 0.4261 - val_accuracy: 0.8015 - val_loss: 0.4118
# Epoch 5/10
#
# Epoch 5: val_accuracy improved from 0.82121 to 0.83788, saving model to InceptionV3_best_model.keras
# 132/132 - 7s - 54ms/step - accuracy: 0.7952 - loss: 0.4299 - val_accuracy: 0.8379 - val_loss: 0.3800
# Epoch 6/10
#
# Epoch 6: val_accuracy did not improve from 0.83788
# 132/132 - 6s - 46ms/step - accuracy: 0.8259 - loss: 0.3897 - val_accuracy: 0.8288 - val_loss: 0.3908
# Epoch 7/10
#
# Epoch 7: val_accuracy did not improve from 0.83788
# 132/132 - 6s - 45ms/step - accuracy: 0.8195 - loss: 0.3807 - val_accuracy: 0.8015 - val_loss: 0.3907
# Epoch 8/10
#
# Epoch 8: val_accuracy did not improve from 0.83788
# 132/132 - 6s - 46ms/step - accuracy: 0.8286 - loss: 0.3741 - val_accuracy: 0.8121 - val_loss: 0.4023
# Epoch 9/10
#
# Epoch 9: val_accuracy did not improve from 0.83788
# 132/132 - 6s - 46ms/step - accuracy: 0.8366 - loss: 0.3733 - val_accuracy: 0.8318 - val_loss: 0.3751
# Epoch 10/10
#
# Epoch 10: val_accuracy did not improve from 0.83788
# 132/132 - 6s - 46ms/step - accuracy: 0.8331 - loss: 0.3688 - val_accuracy: 0.8197 - val_loss: 0.3886
# InceptionV3 validation accuracy: 0.8378787636756897
# Training DenseNet121...
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Epoch 1/10
#
# Epoch 1: val_accuracy improved from -inf to 0.84848, saving model to DenseNet121_best_model.keras
# 132/132 - 71s - 536ms/step - accuracy: 0.7474 - loss: 0.6574 - val_accuracy: 0.8485 - val_loss: 0.3683
# Epoch 2/10
#
# Epoch 2: val_accuracy did not improve from 0.84848
# 132/132 - 6s - 49ms/step - accuracy: 0.7895 - loss: 0.5168 - val_accuracy: 0.8455 - val_loss: 0.3538
# Epoch 3/10
#
# Epoch 3: val_accuracy did not improve from 0.84848
# 132/132 - 6s - 49ms/step - accuracy: 0.8172 - loss: 0.4253 - val_accuracy: 0.8470 - val_loss: 0.3521
# Epoch 4/10
#
# Epoch 4: val_accuracy improved from 0.84848 to 0.86515, saving model to DenseNet121_best_model.keras
# 132/132 - 7s - 57ms/step - accuracy: 0.8210 - loss: 0.4144 - val_accuracy: 0.8652 - val_loss: 0.3137
# Epoch 5/10
#
# Epoch 5: val_accuracy improved from 0.86515 to 0.86818, saving model to DenseNet121_best_model.keras
# 132/132 - 8s - 58ms/step - accuracy: 0.8335 - loss: 0.3741 - val_accuracy: 0.8682 - val_loss: 0.3222
# Epoch 6/10
#
# Epoch 6: val_accuracy improved from 0.86818 to 0.87273, saving model to DenseNet121_best_model.keras
# 132/132 - 8s - 57ms/step - accuracy: 0.8328 - loss: 0.3721 - val_accuracy: 0.8727 - val_loss: 0.2977
# Epoch 7/10
#
# Epoch 7: val_accuracy did not improve from 0.87273
# 132/132 - 7s - 49ms/step - accuracy: 0.8419 - loss: 0.3557 - val_accuracy: 0.8561 - val_loss: 0.3076
# Epoch 8/10
#
# Epoch 8: val_accuracy did not improve from 0.87273
# 132/132 - 6s - 49ms/step - accuracy: 0.8403 - loss: 0.3557 - val_accuracy: 0.8318 - val_loss: 0.3497
# Epoch 9/10
#
# Epoch 9: val_accuracy did not improve from 0.87273
# 132/132 - 7s - 50ms/step - accuracy: 0.8445 - loss: 0.3466 - val_accuracy: 0.8652 - val_loss: 0.3310
# Epoch 10/10
#
# Epoch 10: val_accuracy did not improve from 0.87273
# 132/132 - 7s - 49ms/step - accuracy: 0.8449 - loss: 0.3440 - val_accuracy: 0.8621 - val_loss: 0.3319
# DenseNet121 validation accuracy: 0.8727272748947144
# Training MobileNet...
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17225924/17225924 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Epoch 1/10
#
# Epoch 1: val_accuracy improved from -inf to 0.81515, saving model to MobileNet_best_model.keras
# 132/132 - 23s - 172ms/step - accuracy: 0.7262 - loss: 0.7190 - val_accuracy: 0.8152 - val_loss: 0.4104
# Epoch 2/10
#
# Epoch 2: val_accuracy improved from 0.81515 to 0.84091, saving model to MobileNet_best_model.keras
# 132/132 - 4s - 34ms/step - accuracy: 0.7740 - loss: 0.5621 - val_accuracy: 0.8409 - val_loss: 0.3670
# Epoch 3/10
#
# Epoch 3: val_accuracy improved from 0.84091 to 0.85152, saving model to MobileNet_best_model.keras
# 132/132 - 4s - 33ms/step - accuracy: 0.8028 - loss: 0.4551 - val_accuracy: 0.8515 - val_loss: 0.3384
# Epoch 4/10
#
# Epoch 4: val_accuracy did not improve from 0.85152
# 132/132 - 4s - 30ms/step - accuracy: 0.8256 - loss: 0.4116 - val_accuracy: 0.8455 - val_loss: 0.3380
# Epoch 5/10
#
# Epoch 5: val_accuracy did not improve from 0.85152
# 132/132 - 4s - 31ms/step - accuracy: 0.8271 - loss: 0.3770 - val_accuracy: 0.8455 - val_loss: 0.3325
# Epoch 6/10
#
# Epoch 6: val_accuracy improved from 0.85152 to 0.85455, saving model to MobileNet_best_model.keras
# 132/132 - 4s - 33ms/step - accuracy: 0.8366 - loss: 0.3624 - val_accuracy: 0.8545 - val_loss: 0.3282
# Epoch 7/10
#
# Epoch 7: val_accuracy did not improve from 0.85455
# 132/132 - 4s - 31ms/step - accuracy: 0.8369 - loss: 0.3594 - val_accuracy: 0.8485 - val_loss: 0.3211
# Epoch 8/10
#
# Epoch 8: val_accuracy did not improve from 0.85455
# 132/132 - 4s - 32ms/step - accuracy: 0.8244 - loss: 0.3620 - val_accuracy: 0.8455 - val_loss: 0.3338
# Epoch 9/10
#
# Epoch 9: val_accuracy did not improve from 0.85455
# 132/132 - 4s - 32ms/step - accuracy: 0.8559 - loss: 0.3323 - val_accuracy: 0.8485 - val_loss: 0.3310
# Epoch 10/10
#
# Epoch 10: val_accuracy did not improve from 0.85455
# 132/132 - 4s - 30ms/step - accuracy: 0.8495 - loss: 0.3359 - val_accuracy: 0.8515 - val_loss: 0.3226
# MobileNet validation accuracy: 0.8545454740524292
# Training MobileNetV2...
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Epoch 1/10
#
# Epoch 1: val_accuracy improved from -inf to 0.82727, saving model to MobileNetV2_best_model.keras
# 132/132 - 30s - 228ms/step - accuracy: 0.7395 - loss: 0.7313 - val_accuracy: 0.8273 - val_loss: 0.4251
# Epoch 2/10
#
# Epoch 2: val_accuracy did not improve from 0.82727
# 132/132 - 4s - 30ms/step - accuracy: 0.7664 - loss: 0.5602 - val_accuracy: 0.8136 - val_loss: 0.4310
# Epoch 3/10
#
# Epoch 3: val_accuracy improved from 0.82727 to 0.83485, saving model to MobileNetV2_best_model.keras
# 132/132 - 5s - 35ms/step - accuracy: 0.8024 - loss: 0.4689 - val_accuracy: 0.8348 - val_loss: 0.3792
# Epoch 4/10
#
# Epoch 4: val_accuracy improved from 0.83485 to 0.84091, saving model to MobileNetV2_best_model.keras
# 132/132 - 4s - 34ms/step - accuracy: 0.8119 - loss: 0.4230 - val_accuracy: 0.8409 - val_loss: 0.3692
# Epoch 5/10
#
# Epoch 5: val_accuracy did not improve from 0.84091
# 132/132 - 4s - 30ms/step - accuracy: 0.8142 - loss: 0.4090 - val_accuracy: 0.8333 - val_loss: 0.3559
# Epoch 6/10
#
# Epoch 6: val_accuracy did not improve from 0.84091
# 132/132 - 4s - 32ms/step - accuracy: 0.8286 - loss: 0.3824 - val_accuracy: 0.8348 - val_loss: 0.3608
# Epoch 7/10
#
# Epoch 7: val_accuracy improved from 0.84091 to 0.84394, saving model to MobileNetV2_best_model.keras
# 132/132 - 5s - 35ms/step - accuracy: 0.8328 - loss: 0.3829 - val_accuracy: 0.8439 - val_loss: 0.3642
# Epoch 8/10
#
# Epoch 8: val_accuracy did not improve from 0.84394
# 132/132 - 4s - 31ms/step - accuracy: 0.8316 - loss: 0.3681 - val_accuracy: 0.8348 - val_loss: 0.3632
# Epoch 9/10
#
# Epoch 9: val_accuracy did not improve from 0.84394
# 132/132 - 4s - 32ms/step - accuracy: 0.8438 - loss: 0.3492 - val_accuracy: 0.8439 - val_loss: 0.3727
# Epoch 10/10
#
# Epoch 10: val_accuracy did not improve from 0.84394
# 132/132 - 4s - 29ms/step - accuracy: 0.8415 - loss: 0.3511 - val_accuracy: 0.8409 - val_loss: 0.3591
# MobileNetV2 validation accuracy: 0.8439394235610962
# Training NASNetMobile...
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/nasnet/NASNet-mobile-no-top.h5
# 19993432/19993432 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Epoch 1/10
#
# Epoch 1: val_accuracy improved from -inf to 0.70758, saving model to NASNetMobile_best_model.keras
# 132/132 - 83s - 625ms/step - accuracy: 0.7361 - loss: 0.6972 - val_accuracy: 0.7076 - val_loss: 0.7407
# Epoch 2/10
#
# Epoch 2: val_accuracy improved from 0.70758 to 0.81970, saving model to NASNetMobile_best_model.keras
# 132/132 - 8s - 62ms/step - accuracy: 0.7710 - loss: 0.5423 - val_accuracy: 0.8197 - val_loss: 0.4128
# Epoch 3/10
#
# Epoch 3: val_accuracy improved from 0.81970 to 0.83182, saving model to NASNetMobile_best_model.keras
# 132/132 - 9s - 68ms/step - accuracy: 0.8005 - loss: 0.4601 - val_accuracy: 0.8318 - val_loss: 0.3986
# Epoch 4/10
#
# Epoch 4: val_accuracy did not improve from 0.83182
# 132/132 - 7s - 51ms/step - accuracy: 0.8051 - loss: 0.4261 - val_accuracy: 0.8242 - val_loss: 0.3748
# Epoch 5/10
#
# Epoch 5: val_accuracy did not improve from 0.83182
# 132/132 - 7s - 52ms/step - accuracy: 0.8134 - loss: 0.3991 - val_accuracy: 0.8288 - val_loss: 0.3470
# Epoch 6/10
#
# Epoch 6: val_accuracy did not improve from 0.83182
# 132/132 - 7s - 51ms/step - accuracy: 0.8320 - loss: 0.3877 - val_accuracy: 0.8258 - val_loss: 0.3565
# Epoch 7/10
#
# Epoch 7: val_accuracy improved from 0.83182 to 0.83333, saving model to NASNetMobile_best_model.keras
# 132/132 - 8s - 63ms/step - accuracy: 0.8252 - loss: 0.3782 - val_accuracy: 0.8333 - val_loss: 0.3518
# Epoch 8/10
#
# Epoch 8: val_accuracy improved from 0.83333 to 0.83788, saving model to NASNetMobile_best_model.keras
# 132/132 - 8s - 64ms/step - accuracy: 0.8396 - loss: 0.3561 - val_accuracy: 0.8379 - val_loss: 0.3511
# Epoch 9/10
#
# Epoch 9: val_accuracy did not improve from 0.83788
# 132/132 - 7s - 52ms/step - accuracy: 0.8358 - loss: 0.3631 - val_accuracy: 0.8182 - val_loss: 0.3712
# Epoch 10/10
#
# Epoch 10: val_accuracy did not improve from 0.83788
# 132/132 - 7s - 51ms/step - accuracy: 0.8483 - loss: 0.3341 - val_accuracy: 0.8242 - val_loss: 0.3678
# NASNetMobile validation accuracy: 0.8378787636756897
# Training EfficientNetB0...
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Epoch 1/10
#
# Epoch 1: val_accuracy improved from -inf to 0.54545, saving model to EfficientNetB0_best_model.keras
# 132/132 - 72s - 543ms/step - accuracy: 0.5013 - loss: 1.0736 - val_accuracy: 0.5455 - val_loss: 0.7076
# Epoch 2/10
#
# Epoch 2: val_accuracy did not improve from 0.54545
# 132/132 - 4s - 31ms/step - accuracy: 0.5252 - loss: 0.8931 - val_accuracy: 0.5455 - val_loss: 0.6895
# Epoch 3/10
#
# Epoch 3: val_accuracy did not improve from 0.54545
# 132/132 - 4s - 32ms/step - accuracy: 0.4953 - loss: 0.8463 - val_accuracy: 0.5455 - val_loss: 0.6891
# Epoch 4/10
#
# Epoch 4: val_accuracy did not improve from 0.54545
# 132/132 - 4s - 32ms/step - accuracy: 0.5051 - loss: 0.7747 - val_accuracy: 0.5455 - val_loss: 0.6903
# Epoch 5/10
#
# Epoch 5: val_accuracy did not improve from 0.54545
# 132/132 - 4s - 31ms/step - accuracy: 0.5078 - loss: 0.7443 - val_accuracy: 0.4545 - val_loss: 0.6946
# Epoch 6/10
#
# Epoch 6: val_accuracy did not improve from 0.54545
# 132/132 - 4s - 31ms/step - accuracy: 0.5252 - loss: 0.7284 - val_accuracy: 0.5455 - val_loss: 0.6890
# Epoch 7/10
#
# Epoch 7: val_accuracy did not improve from 0.54545
# 132/132 - 4s - 31ms/step - accuracy: 0.5150 - loss: 0.7224 - val_accuracy: 0.4545 - val_loss: 0.6941
# Epoch 8/10
#
# Epoch 8: val_accuracy did not improve from 0.54545
# 132/132 - 4s - 32ms/step - accuracy: 0.5138 - loss: 0.7252 - val_accuracy: 0.5455 - val_loss: 0.6889
# Epoch 9/10
#
# Epoch 9: val_accuracy did not improve from 0.54545
# 132/132 - 4s - 31ms/step - accuracy: 0.5154 - loss: 0.7182 - val_accuracy: 0.5455 - val_loss: 0.6907
# Epoch 10/10
#
# Epoch 10: val_accuracy did not improve from 0.54545
# 132/132 - 4s - 31ms/step - accuracy: 0.5184 - loss: 0.7112 - val_accuracy: 0.5455 - val_loss: 0.6892
# EfficientNetB0 validation accuracy: 0.5454545617103577
# Training EfficientNetB3...
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb3_notop.h5
# 43941136/43941136 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Epoch 1/10
#
# Epoch 1: val_accuracy improved from -inf to 0.45455, saving model to EfficientNetB3_best_model.keras
# 132/132 - 124s - 942ms/step - accuracy: 0.5135 - loss: 1.0099 - val_accuracy: 0.4545 - val_loss: 0.7395
# Epoch 2/10
#
# Epoch 2: val_accuracy improved from 0.45455 to 0.54545, saving model to EfficientNetB3_best_model.keras
# 132/132 - 8s - 58ms/step - accuracy: 0.5044 - loss: 0.9090 - val_accuracy: 0.5455 - val_loss: 0.6911
# Epoch 3/10
#
# Epoch 3: val_accuracy did not improve from 0.54545
# 132/132 - 6s - 49ms/step - accuracy: 0.5112 - loss: 0.8330 - val_accuracy: 0.4545 - val_loss: 0.7003
# Epoch 4/10
#
# Epoch 4: val_accuracy did not improve from 0.54545
# 132/132 - 7s - 50ms/step - accuracy: 0.5100 - loss: 0.7943 - val_accuracy: 0.4545 - val_loss: 0.6967
# Epoch 5/10
#
# Epoch 5: val_accuracy did not improve from 0.54545
# 132/132 - 7s - 50ms/step - accuracy: 0.5256 - loss: 0.7504 - val_accuracy: 0.4545 - val_loss: 0.6993
# Epoch 6/10
#
# Epoch 6: val_accuracy did not improve from 0.54545
# 132/132 - 7s - 50ms/step - accuracy: 0.4979 - loss: 0.7443 - val_accuracy: 0.4545 - val_loss: 0.7060
# Epoch 7/10
#
# Epoch 7: val_accuracy did not improve from 0.54545
# 132/132 - 7s - 50ms/step - accuracy: 0.5078 - loss: 0.7299 - val_accuracy: 0.4545 - val_loss: 0.7172
# Epoch 8/10
#
# Epoch 8: val_accuracy did not improve from 0.54545
# 132/132 - 6s - 49ms/step - accuracy: 0.5165 - loss: 0.7230 - val_accuracy: 0.5455 - val_loss: 0.6885
# Epoch 9/10
#
# Epoch 9: val_accuracy did not improve from 0.54545
# 132/132 - 6s - 49ms/step - accuracy: 0.5203 - loss: 0.7150 - val_accuracy: 0.5439 - val_loss: 0.6908
# Epoch 10/10
#
# Epoch 10: val_accuracy did not improve from 0.54545
# 132/132 - 7s - 50ms/step - accuracy: 0.5237 - loss: 0.7101 - val_accuracy: 0.5455 - val_loss: 0.6895
# EfficientNetB3 validation accuracy: 0.5454545617103577
# Training EfficientNetB4...
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb4_notop.h5
# 71686520/71686520 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Epoch 1/10
#
# Epoch 1: val_accuracy improved from -inf to 0.54545, saving model to EfficientNetB4_best_model.keras
# 132/132 - 158s - 1s/step - accuracy: 0.4972 - loss: 1.0347 - val_accuracy: 0.5455 - val_loss: 0.6888
# Epoch 2/10
#
# Epoch 2: val_accuracy did not improve from 0.54545
# 132/132 - 8s - 64ms/step - accuracy: 0.5173 - loss: 0.8853 - val_accuracy: 0.5455 - val_loss: 0.6897
# Epoch 3/10
#
# Epoch 3: val_accuracy did not improve from 0.54545
# 132/132 - 8s - 64ms/step - accuracy: 0.4843 - loss: 0.8506 - val_accuracy: 0.4545 - val_loss: 0.8924
# Epoch 4/10
#
# Epoch 4: val_accuracy did not improve from 0.54545
# 132/132 - 9s - 64ms/step - accuracy: 0.5146 - loss: 0.7735 - val_accuracy: 0.4545 - val_loss: 0.7189
# Epoch 5/10
#
# Epoch 5: val_accuracy did not improve from 0.54545
# 132/132 - 9s - 66ms/step - accuracy: 0.5025 - loss: 0.7534 - val_accuracy: 0.4545 - val_loss: 0.6950
# Epoch 6/10
#
# Epoch 6: val_accuracy did not improve from 0.54545
# 132/132 - 8s - 64ms/step - accuracy: 0.5006 - loss: 0.7453 - val_accuracy: 0.5455 - val_loss: 0.7572
# Epoch 7/10
#
# Epoch 7: val_accuracy did not improve from 0.54545
# 132/132 - 8s - 64ms/step - accuracy: 0.5040 - loss: 0.7294 - val_accuracy: 0.5455 - val_loss: 0.6890
# Epoch 8/10
#
# Epoch 8: val_accuracy did not improve from 0.54545
# 132/132 - 8s - 64ms/step - accuracy: 0.5059 - loss: 0.7246 - val_accuracy: 0.5455 - val_loss: 0.6899
# Epoch 9/10
#
# Epoch 9: val_accuracy did not improve from 0.54545
# 132/132 - 9s - 64ms/step - accuracy: 0.5074 - loss: 0.7145 - val_accuracy: 0.5455 - val_loss: 0.6910
# Epoch 10/10
#
# Epoch 10: val_accuracy did not improve from 0.54545
# 132/132 - 9s - 64ms/step - accuracy: 0.5104 - loss: 0.7133 - val_accuracy: 0.5455 - val_loss: 0.6927
# EfficientNetB4 validation accuracy: 0.5454545617103577
# Training ResNet101...
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171446536/171446536 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step
# Epoch 1/10
# W0000 00:00:1724354772.458192      82 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1724354796.811657      83 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Epoch 1: val_accuracy improved from -inf to 0.45455, saving model to ResNet101_best_model.keras
# 132/132 - 51s - 385ms/step - accuracy: 0.7251 - loss: 0.7294 - val_accuracy: 0.4545 - val_loss: 1.6971
# Epoch 2/10
#
# Epoch 2: val_accuracy did not improve from 0.45455
# 132/132 - 10s - 74ms/step - accuracy: 0.7467 - loss: 0.6098 - val_accuracy: 0.4545 - val_loss: 1.5208
# Epoch 3/10
#
# Epoch 3: val_accuracy improved from 0.45455 to 0.75758, saving model to ResNet101_best_model.keras
# 132/132 - 11s - 86ms/step - accuracy: 0.7509 - loss: 0.5547 - val_accuracy: 0.7576 - val_loss: 0.5342
# Epoch 4/10
#
# Epoch 4: val_accuracy did not improve from 0.75758
# 132/132 - 10s - 74ms/step - accuracy: 0.7527 - loss: 0.5323 - val_accuracy: 0.4712 - val_loss: 0.8537
# Epoch 5/10
#
# Epoch 5: val_accuracy did not improve from 0.75758
# 132/132 - 10s - 74ms/step - accuracy: 0.7804 - loss: 0.4761 - val_accuracy: 0.5258 - val_loss: 1.0496
# Epoch 6/10
#
# Epoch 6: val_accuracy improved from 0.75758 to 0.78485, saving model to ResNet101_best_model.keras
# 132/132 - 11s - 87ms/step - accuracy: 0.7861 - loss: 0.4769 - val_accuracy: 0.7848 - val_loss: 0.4382
# Epoch 7/10
#
# Epoch 7: val_accuracy did not improve from 0.78485
# 132/132 - 19s - 141ms/step - accuracy: 0.7918 - loss: 0.4585 - val_accuracy: 0.5652 - val_loss: 2.4221
# Epoch 8/10
#
# Epoch 8: val_accuracy did not improve from 0.78485
# 132/132 - 10s - 74ms/step - accuracy: 0.7903 - loss: 0.4455 - val_accuracy: 0.7561 - val_loss: 0.6518
# Epoch 9/10
#
# Epoch 9: val_accuracy did not improve from 0.78485
# 132/132 - 10s - 74ms/step - accuracy: 0.7903 - loss: 0.4463 - val_accuracy: 0.7167 - val_loss: 0.5653
# Epoch 10/10
#
# Epoch 10: val_accuracy did not improve from 0.78485
# 132/132 - 10s - 73ms/step - accuracy: 0.8013 - loss: 0.4378 - val_accuracy: 0.5955 - val_loss: 2.2819
# ResNet101 validation accuracy: 0.7848485112190247
# Training ResNet152...
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234698864/234698864 ━━━━━━━━━━━━━━━━━━━━ 6s 0us/step
# Epoch 1/10
# W0000 00:00:1724354944.891555      84 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1724354978.807834      82 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Epoch 1: val_accuracy improved from -inf to 0.45455, saving model to ResNet152_best_model.keras
# 132/132 - 72s - 546ms/step - accuracy: 0.7311 - loss: 0.6965 - val_accuracy: 0.4545 - val_loss: 0.8189
# Epoch 2/10
#
# Epoch 2: val_accuracy did not improve from 0.45455
# 132/132 - 14s - 104ms/step - accuracy: 0.7501 - loss: 0.5850 - val_accuracy: 0.4545 - val_loss: 1.1730
# Epoch 3/10
#
# Epoch 3: val_accuracy improved from 0.45455 to 0.55152, saving model to ResNet152_best_model.keras
# 132/132 - 16s - 122ms/step - accuracy: 0.7782 - loss: 0.5097 - val_accuracy: 0.5515 - val_loss: 1.5693
# Epoch 4/10
#
# Epoch 4: val_accuracy improved from 0.55152 to 0.75909, saving model to ResNet152_best_model.keras
# 132/132 - 16s - 121ms/step - accuracy: 0.7706 - loss: 0.5047 - val_accuracy: 0.7591 - val_loss: 0.4545
# Epoch 5/10
#
# Epoch 5: val_accuracy did not improve from 0.75909
# 132/132 - 14s - 105ms/step - accuracy: 0.7911 - loss: 0.4685 - val_accuracy: 0.6045 - val_loss: 1.2011
# Epoch 6/10
#
# Epoch 6: val_accuracy did not improve from 0.75909
# 132/132 - 14s - 104ms/step - accuracy: 0.7895 - loss: 0.4596 - val_accuracy: 0.7333 - val_loss: 0.5345
# Epoch 7/10
#
# Epoch 7: val_accuracy did not improve from 0.75909
# 132/132 - 14s - 103ms/step - accuracy: 0.7907 - loss: 0.4474 - val_accuracy: 0.5636 - val_loss: 2.6869
# Epoch 8/10
#
# Epoch 8: val_accuracy did not improve from 0.75909
# 132/132 - 14s - 104ms/step - accuracy: 0.7971 - loss: 0.4284 - val_accuracy: 0.5576 - val_loss: 4.3347
# Epoch 9/10
#
# Epoch 9: val_accuracy did not improve from 0.75909
# 132/132 - 14s - 103ms/step - accuracy: 0.7994 - loss: 0.4340 - val_accuracy: 0.5576 - val_loss: 2.6915
# Epoch 10/10
#
# Epoch 10: val_accuracy did not improve from 0.75909
# 132/132 - 14s - 104ms/step - accuracy: 0.8051 - loss: 0.4269 - val_accuracy: 0.5894 - val_loss: 1.6630
# ResNet152 validation accuracy: 0.7590909004211426
# The best performing model is DenseNet121 with a validation accuracy of 0.8727272748947144

# %% [markdown]
# ## 6. Results

# %% [markdown]
# | Model                  | Validation Accuracy |
# |------------------------|----------------------|
# | DenseNet121            | 0.8621               |
# | DenseNet169            | 0.8460               |
# | DenseNet201            | 0.8440               |
# | InceptionV3            | 0.8530               |
# | EfficientNetB0         | 0.8410               |
# | InceptionResNetV2      | 0.8420               |
# | Xception               | 0.8394               |
# | VGG16                  | 0.8333               |
# | VGG19                  | 0.8250               |
# | MobileNetV2            | 0.7960               |
# | NASNetMobile           | 0.7870               |
# | MobileNetV3Small       | 0.7850               |
# | ResNet101              | 0.7890               |
# | ResNet50               | 0.7727               |

# %% [markdown]
# <div class="alert alert-block alert-secondary" style="font-size:14px; font-family:verdana; background-color:#d3d3d3; color:#555555;">
#     📌 The best model during the initial test is DenseNet121. We will use this model and train it for more epochs to achieve better results.
# </div>

# %% [markdown]
# ## 7. Training The Winning Model

# %%
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, BatchNormalization

# Load the pre-trained DenseNet121 model with ImageNet weights, without the top (classification) layers
base_model = DenseNet121(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the base model layers
base_model.trainable = False

# Add custom layers on top of the pre-trained model
x = base_model.output
x = GlobalAveragePooling2D()(x)  # Global average pooling to reduce the feature maps
x = Dense(1024, activation='relu')(x)  # Fully connected layer with 1024 units
x = BatchNormalization()(x)  # Add batch normalization
x = Dropout(0.8)(x)  # Dropout for regularization
x = Dense(512, activation='relu')(x)  # Fully connected layer with 512 units
x = BatchNormalization()(x)  # Add batch normalization
x = Dropout(0.5)(x)  # Dropout for regularization
predictions = Dense(1, activation='sigmoid')(x)  # Final layer for binary classification

# Create the final model
model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Display the model summary
model.summary()
# Out:
# Model: "functional_13"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_13      │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_6    │ (None, 230, 230,  │          0 │ input_layer_13[0… │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_conv (Conv2D) │ (None, 112, 112,  │      9,408 │ zero_padding2d_6… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_bn            │ (None, 112, 112,  │        256 │ conv1_conv[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_relu          │ (None, 112, 112,  │          0 │ conv1_bn[0][0]    │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_7    │ (None, 114, 114,  │          0 │ conv1_relu[0][0]  │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1               │ (None, 56, 56,    │          0 │ zero_padding2d_7… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_bn   │ (None, 56, 56,    │        256 │ pool1[0][0]       │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_relu │ (None, 56, 56,    │          0 │ conv2_block1_0_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_conv │ (None, 56, 56,    │      8,192 │ conv2_block1_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_bn   │ (None, 56, 56,    │        512 │ conv2_block1_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_relu │ (None, 56, 56,    │          0 │ conv2_block1_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_conv │ (None, 56, 56,    │     36,864 │ conv2_block1_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_concat │ (None, 56, 56,    │          0 │ pool1[0][0],      │
# │ (Concatenate)       │ 96)               │            │ conv2_block1_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_0_bn   │ (None, 56, 56,    │        384 │ conv2_block1_con… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_0_relu │ (None, 56, 56,    │          0 │ conv2_block2_0_b… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_conv │ (None, 56, 56,    │     12,288 │ conv2_block2_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_bn   │ (None, 56, 56,    │        512 │ conv2_block2_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_relu │ (None, 56, 56,    │          0 │ conv2_block2_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_conv │ (None, 56, 56,    │     36,864 │ conv2_block2_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_concat │ (None, 56, 56,    │          0 │ conv2_block1_con… │
# │ (Concatenate)       │ 128)              │            │ conv2_block2_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_0_bn   │ (None, 56, 56,    │        512 │ conv2_block2_con… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_0_relu │ (None, 56, 56,    │          0 │ conv2_block3_0_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_conv │ (None, 56, 56,    │     16,384 │ conv2_block3_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_bn   │ (None, 56, 56,    │        512 │ conv2_block3_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_relu │ (None, 56, 56,    │          0 │ conv2_block3_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_conv │ (None, 56, 56,    │     36,864 │ conv2_block3_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_concat │ (None, 56, 56,    │          0 │ conv2_block2_con… │
# │ (Concatenate)       │ 160)              │            │ conv2_block3_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block4_0_bn   │ (None, 56, 56,    │        640 │ conv2_block3_con… │
# │ (BatchNormalizatio… │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block4_0_relu │ (None, 56, 56,    │          0 │ conv2_block4_0_b… │
# │ (Activation)        │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block4_1_conv │ (None, 56, 56,    │     20,480 │ conv2_block4_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block4_1_bn   │ (None, 56, 56,    │        512 │ conv2_block4_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block4_1_relu │ (None, 56, 56,    │          0 │ conv2_block4_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block4_2_conv │ (None, 56, 56,    │     36,864 │ conv2_block4_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block4_concat │ (None, 56, 56,    │          0 │ conv2_block3_con… │
# │ (Concatenate)       │ 192)              │            │ conv2_block4_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block5_0_bn   │ (None, 56, 56,    │        768 │ conv2_block4_con… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block5_0_relu │ (None, 56, 56,    │          0 │ conv2_block5_0_b… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block5_1_conv │ (None, 56, 56,    │     24,576 │ conv2_block5_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block5_1_bn   │ (None, 56, 56,    │        512 │ conv2_block5_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block5_1_relu │ (None, 56, 56,    │          0 │ conv2_block5_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block5_2_conv │ (None, 56, 56,    │     36,864 │ conv2_block5_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block5_concat │ (None, 56, 56,    │          0 │ conv2_block4_con… │
# │ (Concatenate)       │ 224)              │            │ conv2_block5_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block6_0_bn   │ (None, 56, 56,    │        896 │ conv2_block5_con… │
# │ (BatchNormalizatio… │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block6_0_relu │ (None, 56, 56,    │          0 │ conv2_block6_0_b… │
# │ (Activation)        │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block6_1_conv │ (None, 56, 56,    │     28,672 │ conv2_block6_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block6_1_bn   │ (None, 56, 56,    │        512 │ conv2_block6_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block6_1_relu │ (None, 56, 56,    │          0 │ conv2_block6_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block6_2_conv │ (None, 56, 56,    │     36,864 │ conv2_block6_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block6_concat │ (None, 56, 56,    │          0 │ conv2_block5_con… │
# │ (Concatenate)       │ 256)              │            │ conv2_block6_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool2_bn            │ (None, 56, 56,    │      1,024 │ conv2_block6_con… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool2_relu          │ (None, 56, 56,    │          0 │ pool2_bn[0][0]    │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool2_conv (Conv2D) │ (None, 56, 56,    │     32,768 │ pool2_relu[0][0]  │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool2_pool          │ (None, 28, 28,    │          0 │ pool2_conv[0][0]  │
# │ (AveragePooling2D)  │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_bn   │ (None, 28, 28,    │        512 │ pool2_pool[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_relu │ (None, 28, 28,    │          0 │ conv3_block1_0_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_conv │ (None, 28, 28,    │     16,384 │ conv3_block1_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_bn   │ (None, 28, 28,    │        512 │ conv3_block1_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_relu │ (None, 28, 28,    │          0 │ conv3_block1_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_conv │ (None, 28, 28,    │     36,864 │ conv3_block1_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_concat │ (None, 28, 28,    │          0 │ pool2_pool[0][0], │
# │ (Concatenate)       │ 160)              │            │ conv3_block1_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_0_bn   │ (None, 28, 28,    │        640 │ conv3_block1_con… │
# │ (BatchNormalizatio… │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_0_relu │ (None, 28, 28,    │          0 │ conv3_block2_0_b… │
# │ (Activation)        │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_conv │ (None, 28, 28,    │     20,480 │ conv3_block2_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_bn   │ (None, 28, 28,    │        512 │ conv3_block2_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_relu │ (None, 28, 28,    │          0 │ conv3_block2_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_conv │ (None, 28, 28,    │     36,864 │ conv3_block2_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_concat │ (None, 28, 28,    │          0 │ conv3_block1_con… │
# │ (Concatenate)       │ 192)              │            │ conv3_block2_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_0_bn   │ (None, 28, 28,    │        768 │ conv3_block2_con… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_0_relu │ (None, 28, 28,    │          0 │ conv3_block3_0_b… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_conv │ (None, 28, 28,    │     24,576 │ conv3_block3_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_bn   │ (None, 28, 28,    │        512 │ conv3_block3_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_relu │ (None, 28, 28,    │          0 │ conv3_block3_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_conv │ (None, 28, 28,    │     36,864 │ conv3_block3_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_concat │ (None, 28, 28,    │          0 │ conv3_block2_con… │
# │ (Concatenate)       │ 224)              │            │ conv3_block3_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_0_bn   │ (None, 28, 28,    │        896 │ conv3_block3_con… │
# │ (BatchNormalizatio… │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_0_relu │ (None, 28, 28,    │          0 │ conv3_block4_0_b… │
# │ (Activation)        │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_conv │ (None, 28, 28,    │     28,672 │ conv3_block4_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_bn   │ (None, 28, 28,    │        512 │ conv3_block4_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_relu │ (None, 28, 28,    │          0 │ conv3_block4_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_conv │ (None, 28, 28,    │     36,864 │ conv3_block4_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_concat │ (None, 28, 28,    │          0 │ conv3_block3_con… │
# │ (Concatenate)       │ 256)              │            │ conv3_block4_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_0_bn   │ (None, 28, 28,    │      1,024 │ conv3_block4_con… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_0_relu │ (None, 28, 28,    │          0 │ conv3_block5_0_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_1_conv │ (None, 28, 28,    │     32,768 │ conv3_block5_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_1_bn   │ (None, 28, 28,    │        512 │ conv3_block5_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_1_relu │ (None, 28, 28,    │          0 │ conv3_block5_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_2_conv │ (None, 28, 28,    │     36,864 │ conv3_block5_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_concat │ (None, 28, 28,    │          0 │ conv3_block4_con… │
# │ (Concatenate)       │ 288)              │            │ conv3_block5_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_0_bn   │ (None, 28, 28,    │      1,152 │ conv3_block5_con… │
# │ (BatchNormalizatio… │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_0_relu │ (None, 28, 28,    │          0 │ conv3_block6_0_b… │
# │ (Activation)        │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_1_conv │ (None, 28, 28,    │     36,864 │ conv3_block6_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_1_bn   │ (None, 28, 28,    │        512 │ conv3_block6_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_1_relu │ (None, 28, 28,    │          0 │ conv3_block6_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_2_conv │ (None, 28, 28,    │     36,864 │ conv3_block6_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_concat │ (None, 28, 28,    │          0 │ conv3_block5_con… │
# │ (Concatenate)       │ 320)              │            │ conv3_block6_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_0_bn   │ (None, 28, 28,    │      1,280 │ conv3_block6_con… │
# │ (BatchNormalizatio… │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_0_relu │ (None, 28, 28,    │          0 │ conv3_block7_0_b… │
# │ (Activation)        │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_1_conv │ (None, 28, 28,    │     40,960 │ conv3_block7_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_1_bn   │ (None, 28, 28,    │        512 │ conv3_block7_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_1_relu │ (None, 28, 28,    │          0 │ conv3_block7_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_2_conv │ (None, 28, 28,    │     36,864 │ conv3_block7_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_concat │ (None, 28, 28,    │          0 │ conv3_block6_con… │
# │ (Concatenate)       │ 352)              │            │ conv3_block7_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block8_0_bn   │ (None, 28, 28,    │      1,408 │ conv3_block7_con… │
# │ (BatchNormalizatio… │ 352)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block8_0_relu │ (None, 28, 28,    │          0 │ conv3_block8_0_b… │
# │ (Activation)        │ 352)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block8_1_conv │ (None, 28, 28,    │     45,056 │ conv3_block8_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block8_1_bn   │ (None, 28, 28,    │        512 │ conv3_block8_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block8_1_relu │ (None, 28, 28,    │          0 │ conv3_block8_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block8_2_conv │ (None, 28, 28,    │     36,864 │ conv3_block8_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block8_concat │ (None, 28, 28,    │          0 │ conv3_block7_con… │
# │ (Concatenate)       │ 384)              │            │ conv3_block8_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block9_0_bn   │ (None, 28, 28,    │      1,536 │ conv3_block8_con… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block9_0_relu │ (None, 28, 28,    │          0 │ conv3_block9_0_b… │
# │ (Activation)        │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block9_1_conv │ (None, 28, 28,    │     49,152 │ conv3_block9_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block9_1_bn   │ (None, 28, 28,    │        512 │ conv3_block9_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block9_1_relu │ (None, 28, 28,    │          0 │ conv3_block9_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block9_2_conv │ (None, 28, 28,    │     36,864 │ conv3_block9_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block9_concat │ (None, 28, 28,    │          0 │ conv3_block8_con… │
# │ (Concatenate)       │ 416)              │            │ conv3_block9_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block10_0_bn  │ (None, 28, 28,    │      1,664 │ conv3_block9_con… │
# │ (BatchNormalizatio… │ 416)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block10_0_re… │ (None, 28, 28,    │          0 │ conv3_block10_0_… │
# │ (Activation)        │ 416)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block10_1_co… │ (None, 28, 28,    │     53,248 │ conv3_block10_0_… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block10_1_bn  │ (None, 28, 28,    │        512 │ conv3_block10_1_… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block10_1_re… │ (None, 28, 28,    │          0 │ conv3_block10_1_… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block10_2_co… │ (None, 28, 28,    │     36,864 │ conv3_block10_1_… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block10_conc… │ (None, 28, 28,    │          0 │ conv3_block9_con… │
# │ (Concatenate)       │ 448)              │            │ conv3_block10_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block11_0_bn  │ (None, 28, 28,    │      1,792 │ conv3_block10_co… │
# │ (BatchNormalizatio… │ 448)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block11_0_re… │ (None, 28, 28,    │          0 │ conv3_block11_0_… │
# │ (Activation)        │ 448)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block11_1_co… │ (None, 28, 28,    │     57,344 │ conv3_block11_0_… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block11_1_bn  │ (None, 28, 28,    │        512 │ conv3_block11_1_… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block11_1_re… │ (None, 28, 28,    │          0 │ conv3_block11_1_… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block11_2_co… │ (None, 28, 28,    │     36,864 │ conv3_block11_1_… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block11_conc… │ (None, 28, 28,    │          0 │ conv3_block10_co… │
# │ (Concatenate)       │ 480)              │            │ conv3_block11_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block12_0_bn  │ (None, 28, 28,    │      1,920 │ conv3_block11_co… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block12_0_re… │ (None, 28, 28,    │          0 │ conv3_block12_0_… │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block12_1_co… │ (None, 28, 28,    │     61,440 │ conv3_block12_0_… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block12_1_bn  │ (None, 28, 28,    │        512 │ conv3_block12_1_… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block12_1_re… │ (None, 28, 28,    │          0 │ conv3_block12_1_… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block12_2_co… │ (None, 28, 28,    │     36,864 │ conv3_block12_1_… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block12_conc… │ (None, 28, 28,    │          0 │ conv3_block11_co… │
# │ (Concatenate)       │ 512)              │            │ conv3_block12_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool3_bn            │ (None, 28, 28,    │      2,048 │ conv3_block12_co… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool3_relu          │ (None, 28, 28,    │          0 │ pool3_bn[0][0]    │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool3_conv (Conv2D) │ (None, 28, 28,    │    131,072 │ pool3_relu[0][0]  │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool3_pool          │ (None, 14, 14,    │          0 │ pool3_conv[0][0]  │
# │ (AveragePooling2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_0_bn   │ (None, 14, 14,    │      1,024 │ pool3_pool[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_0_relu │ (None, 14, 14,    │          0 │ conv4_block1_0_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_conv │ (None, 14, 14,    │     32,768 │ conv4_block1_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_bn   │ (None, 14, 14,    │        512 │ conv4_block1_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_relu │ (None, 14, 14,    │          0 │ conv4_block1_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_conv │ (None, 14, 14,    │     36,864 │ conv4_block1_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_concat │ (None, 14, 14,    │          0 │ pool3_pool[0][0], │
# │ (Concatenate)       │ 288)              │            │ conv4_block1_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_0_bn   │ (None, 14, 14,    │      1,152 │ conv4_block1_con… │
# │ (BatchNormalizatio… │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_0_relu │ (None, 14, 14,    │          0 │ conv4_block2_0_b… │
# │ (Activation)        │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_conv │ (None, 14, 14,    │     36,864 │ conv4_block2_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_bn   │ (None, 14, 14,    │        512 │ conv4_block2_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_relu │ (None, 14, 14,    │          0 │ conv4_block2_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_conv │ (None, 14, 14,    │     36,864 │ conv4_block2_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_concat │ (None, 14, 14,    │          0 │ conv4_block1_con… │
# │ (Concatenate)       │ 320)              │            │ conv4_block2_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_0_bn   │ (None, 14, 14,    │      1,280 │ conv4_block2_con… │
# │ (BatchNormalizatio… │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_0_relu │ (None, 14, 14,    │          0 │ conv4_block3_0_b… │
# │ (Activation)        │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_conv │ (None, 14, 14,    │     40,960 │ conv4_block3_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_bn   │ (None, 14, 14,    │        512 │ conv4_block3_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_relu │ (None, 14, 14,    │          0 │ conv4_block3_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_conv │ (None, 14, 14,    │     36,864 │ conv4_block3_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_concat │ (None, 14, 14,    │          0 │ conv4_block2_con… │
# │ (Concatenate)       │ 352)              │            │ conv4_block3_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_0_bn   │ (None, 14, 14,    │      1,408 │ conv4_block3_con… │
# │ (BatchNormalizatio… │ 352)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_0_relu │ (None, 14, 14,    │          0 │ conv4_block4_0_b… │
# │ (Activation)        │ 352)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_conv │ (None, 14, 14,    │     45,056 │ conv4_block4_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_bn   │ (None, 14, 14,    │        512 │ conv4_block4_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_relu │ (None, 14, 14,    │          0 │ conv4_block4_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_conv │ (None, 14, 14,    │     36,864 │ conv4_block4_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_concat │ (None, 14, 14,    │          0 │ conv4_block3_con… │
# │ (Concatenate)       │ 384)              │            │ conv4_block4_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_0_bn   │ (None, 14, 14,    │      1,536 │ conv4_block4_con… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_0_relu │ (None, 14, 14,    │          0 │ conv4_block5_0_b… │
# │ (Activation)        │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_conv │ (None, 14, 14,    │     49,152 │ conv4_block5_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_bn   │ (None, 14, 14,    │        512 │ conv4_block5_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_relu │ (None, 14, 14,    │          0 │ conv4_block5_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_conv │ (None, 14, 14,    │     36,864 │ conv4_block5_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_concat │ (None, 14, 14,    │          0 │ conv4_block4_con… │
# │ (Concatenate)       │ 416)              │            │ conv4_block5_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_0_bn   │ (None, 14, 14,    │      1,664 │ conv4_block5_con… │
# │ (BatchNormalizatio… │ 416)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_0_relu │ (None, 14, 14,    │          0 │ conv4_block6_0_b… │
# │ (Activation)        │ 416)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_conv │ (None, 14, 14,    │     53,248 │ conv4_block6_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_bn   │ (None, 14, 14,    │        512 │ conv4_block6_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_relu │ (None, 14, 14,    │          0 │ conv4_block6_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_conv │ (None, 14, 14,    │     36,864 │ conv4_block6_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_concat │ (None, 14, 14,    │          0 │ conv4_block5_con… │
# │ (Concatenate)       │ 448)              │            │ conv4_block6_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block7_0_bn   │ (None, 14, 14,    │      1,792 │ conv4_block6_con… │
# │ (BatchNormalizatio… │ 448)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block7_0_relu │ (None, 14, 14,    │          0 │ conv4_block7_0_b… │
# │ (Activation)        │ 448)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block7_1_conv │ (None, 14, 14,    │     57,344 │ conv4_block7_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block7_1_bn   │ (None, 14, 14,    │        512 │ conv4_block7_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block7_1_relu │ (None, 14, 14,    │          0 │ conv4_block7_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block7_2_conv │ (None, 14, 14,    │     36,864 │ conv4_block7_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block7_concat │ (None, 14, 14,    │          0 │ conv4_block6_con… │
# │ (Concatenate)       │ 480)              │            │ conv4_block7_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block8_0_bn   │ (None, 14, 14,    │      1,920 │ conv4_block7_con… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block8_0_relu │ (None, 14, 14,    │          0 │ conv4_block8_0_b… │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block8_1_conv │ (None, 14, 14,    │     61,440 │ conv4_block8_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block8_1_bn   │ (None, 14, 14,    │        512 │ conv4_block8_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block8_1_relu │ (None, 14, 14,    │          0 │ conv4_block8_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block8_2_conv │ (None, 14, 14,    │     36,864 │ conv4_block8_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block8_concat │ (None, 14, 14,    │          0 │ conv4_block7_con… │
# │ (Concatenate)       │ 512)              │            │ conv4_block8_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block9_0_bn   │ (None, 14, 14,    │      2,048 │ conv4_block8_con… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block9_0_relu │ (None, 14, 14,    │          0 │ conv4_block9_0_b… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block9_1_conv │ (None, 14, 14,    │     65,536 │ conv4_block9_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block9_1_bn   │ (None, 14, 14,    │        512 │ conv4_block9_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block9_1_relu │ (None, 14, 14,    │          0 │ conv4_block9_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block9_2_conv │ (None, 14, 14,    │     36,864 │ conv4_block9_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block9_concat │ (None, 14, 14,    │          0 │ conv4_block8_con… │
# │ (Concatenate)       │ 544)              │            │ conv4_block9_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block10_0_bn  │ (None, 14, 14,    │      2,176 │ conv4_block9_con… │
# │ (BatchNormalizatio… │ 544)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block10_0_re… │ (None, 14, 14,    │          0 │ conv4_block10_0_… │
# │ (Activation)        │ 544)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block10_1_co… │ (None, 14, 14,    │     69,632 │ conv4_block10_0_… │
# │ (Conv2D)            │ 128)              │            │                   │
# ...
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block8_1_relu │ (None, 7, 7, 128) │          0 │ conv5_block8_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block8_2_conv │ (None, 7, 7, 32)  │     36,864 │ conv5_block8_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block8_concat │ (None, 7, 7, 768) │          0 │ conv5_block7_con… │
# │ (Concatenate)       │                   │            │ conv5_block8_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block9_0_bn   │ (None, 7, 7, 768) │      3,072 │ conv5_block8_con… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block9_0_relu │ (None, 7, 7, 768) │          0 │ conv5_block9_0_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block9_1_conv │ (None, 7, 7, 128) │     98,304 │ conv5_block9_0_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block9_1_bn   │ (None, 7, 7, 128) │        512 │ conv5_block9_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block9_1_relu │ (None, 7, 7, 128) │          0 │ conv5_block9_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block9_2_conv │ (None, 7, 7, 32)  │     36,864 │ conv5_block9_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block9_concat │ (None, 7, 7, 800) │          0 │ conv5_block8_con… │
# │ (Concatenate)       │                   │            │ conv5_block9_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block10_0_bn  │ (None, 7, 7, 800) │      3,200 │ conv5_block9_con… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block10_0_re… │ (None, 7, 7, 800) │          0 │ conv5_block10_0_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block10_1_co… │ (None, 7, 7, 128) │    102,400 │ conv5_block10_0_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block10_1_bn  │ (None, 7, 7, 128) │        512 │ conv5_block10_1_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block10_1_re… │ (None, 7, 7, 128) │          0 │ conv5_block10_1_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block10_2_co… │ (None, 7, 7, 32)  │     36,864 │ conv5_block10_1_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block10_conc… │ (None, 7, 7, 832) │          0 │ conv5_block9_con… │
# │ (Concatenate)       │                   │            │ conv5_block10_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block11_0_bn  │ (None, 7, 7, 832) │      3,328 │ conv5_block10_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block11_0_re… │ (None, 7, 7, 832) │          0 │ conv5_block11_0_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block11_1_co… │ (None, 7, 7, 128) │    106,496 │ conv5_block11_0_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block11_1_bn  │ (None, 7, 7, 128) │        512 │ conv5_block11_1_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block11_1_re… │ (None, 7, 7, 128) │          0 │ conv5_block11_1_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block11_2_co… │ (None, 7, 7, 32)  │     36,864 │ conv5_block11_1_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block11_conc… │ (None, 7, 7, 864) │          0 │ conv5_block10_co… │
# │ (Concatenate)       │                   │            │ conv5_block11_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block12_0_bn  │ (None, 7, 7, 864) │      3,456 │ conv5_block11_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block12_0_re… │ (None, 7, 7, 864) │          0 │ conv5_block12_0_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block12_1_co… │ (None, 7, 7, 128) │    110,592 │ conv5_block12_0_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block12_1_bn  │ (None, 7, 7, 128) │        512 │ conv5_block12_1_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block12_1_re… │ (None, 7, 7, 128) │          0 │ conv5_block12_1_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block12_2_co… │ (None, 7, 7, 32)  │     36,864 │ conv5_block12_1_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block12_conc… │ (None, 7, 7, 896) │          0 │ conv5_block11_co… │
# │ (Concatenate)       │                   │            │ conv5_block12_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block13_0_bn  │ (None, 7, 7, 896) │      3,584 │ conv5_block12_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block13_0_re… │ (None, 7, 7, 896) │          0 │ conv5_block13_0_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block13_1_co… │ (None, 7, 7, 128) │    114,688 │ conv5_block13_0_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block13_1_bn  │ (None, 7, 7, 128) │        512 │ conv5_block13_1_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block13_1_re… │ (None, 7, 7, 128) │          0 │ conv5_block13_1_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block13_2_co… │ (None, 7, 7, 32)  │     36,864 │ conv5_block13_1_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block13_conc… │ (None, 7, 7, 928) │          0 │ conv5_block12_co… │
# │ (Concatenate)       │                   │            │ conv5_block13_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block14_0_bn  │ (None, 7, 7, 928) │      3,712 │ conv5_block13_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block14_0_re… │ (None, 7, 7, 928) │          0 │ conv5_block14_0_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block14_1_co… │ (None, 7, 7, 128) │    118,784 │ conv5_block14_0_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block14_1_bn  │ (None, 7, 7, 128) │        512 │ conv5_block14_1_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block14_1_re… │ (None, 7, 7, 128) │          0 │ conv5_block14_1_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block14_2_co… │ (None, 7, 7, 32)  │     36,864 │ conv5_block14_1_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block14_conc… │ (None, 7, 7, 960) │          0 │ conv5_block13_co… │
# │ (Concatenate)       │                   │            │ conv5_block14_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block15_0_bn  │ (None, 7, 7, 960) │      3,840 │ conv5_block14_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block15_0_re… │ (None, 7, 7, 960) │          0 │ conv5_block15_0_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block15_1_co… │ (None, 7, 7, 128) │    122,880 │ conv5_block15_0_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block15_1_bn  │ (None, 7, 7, 128) │        512 │ conv5_block15_1_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block15_1_re… │ (None, 7, 7, 128) │          0 │ conv5_block15_1_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block15_2_co… │ (None, 7, 7, 32)  │     36,864 │ conv5_block15_1_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block15_conc… │ (None, 7, 7, 992) │          0 │ conv5_block14_co… │
# │ (Concatenate)       │                   │            │ conv5_block15_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block16_0_bn  │ (None, 7, 7, 992) │      3,968 │ conv5_block15_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block16_0_re… │ (None, 7, 7, 992) │          0 │ conv5_block16_0_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block16_1_co… │ (None, 7, 7, 128) │    126,976 │ conv5_block16_0_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block16_1_bn  │ (None, 7, 7, 128) │        512 │ conv5_block16_1_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block16_1_re… │ (None, 7, 7, 128) │          0 │ conv5_block16_1_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block16_2_co… │ (None, 7, 7, 32)  │     36,864 │ conv5_block16_1_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block16_conc… │ (None, 7, 7,      │          0 │ conv5_block15_co… │
# │ (Concatenate)       │ 1024)             │            │ conv5_block16_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn                  │ (None, 7, 7,      │      4,096 │ conv5_block16_co… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ relu (Activation)   │ (None, 7, 7,      │          0 │ bn[0][0]          │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1024)      │          0 │ relu[0][0]        │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_39 (Dense)    │ (None, 1024)      │  1,049,600 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1024)      │      4,096 │ dense_39[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_26          │ (None, 1024)      │          0 │ batch_normalizat… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_40 (Dense)    │ (None, 512)       │    524,800 │ dropout_26[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512)       │      2,048 │ dense_40[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_27          │ (None, 512)       │          0 │ batch_normalizat… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_41 (Dense)    │ (None, 1)         │        513 │ dropout_27[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 8,618,561 (32.88 MB)
#  Trainable params: 1,577,985 (6.02 MB)
#  Non-trainable params: 7,040,576 (26.86 MB)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint


# Save the model with the best validation accuracy
checkpoint = ModelCheckpoint('best_model.keras', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

# Train the model on the data
history = model.fit(
    train_generator,
    epochs=150,
    validation_data=test_generator,
    verbose=2,
    callbacks=[checkpoint]  # Include the callback
)

# Save training history
train_accuracy = history.history['accuracy']
train_loss = history.history['loss']
val_accuracy = history.history['val_accuracy']
val_loss = history.history['val_loss']
# Out:
# Epoch 1/150
#
# Epoch 1: val_accuracy improved from -inf to 0.85909, saving model to best_model.keras
# 132/132 - 54s - 406ms/step - accuracy: 0.7512 - loss: 0.6480 - val_accuracy: 0.8591 - val_loss: 0.3466
# Epoch 2/150
#
# Epoch 2: val_accuracy did not improve from 0.85909
# 132/132 - 6s - 49ms/step - accuracy: 0.7884 - loss: 0.5090 - val_accuracy: 0.8409 - val_loss: 0.3779
# Epoch 3/150
#
# Epoch 3: val_accuracy did not improve from 0.85909
# 132/132 - 7s - 50ms/step - accuracy: 0.8051 - loss: 0.4634 - val_accuracy: 0.8545 - val_loss: 0.3188
# Epoch 4/150
#
# Epoch 4: val_accuracy improved from 0.85909 to 0.86667, saving model to best_model.keras
# 132/132 - 8s - 57ms/step - accuracy: 0.8191 - loss: 0.4071 - val_accuracy: 0.8667 - val_loss: 0.3041
# Epoch 5/150
#
# Epoch 5: val_accuracy did not improve from 0.86667
# 132/132 - 7s - 50ms/step - accuracy: 0.8267 - loss: 0.3913 - val_accuracy: 0.8621 - val_loss: 0.3142
# Epoch 6/150
#
# Epoch 6: val_accuracy did not improve from 0.86667
# 132/132 - 7s - 50ms/step - accuracy: 0.8203 - loss: 0.3836 - val_accuracy: 0.8561 - val_loss: 0.3097
# Epoch 7/150
#
# Epoch 7: val_accuracy did not improve from 0.86667
# 132/132 - 7s - 50ms/step - accuracy: 0.8426 - loss: 0.3572 - val_accuracy: 0.8576 - val_loss: 0.3144
# Epoch 8/150
#
# Epoch 8: val_accuracy did not improve from 0.86667
# 132/132 - 7s - 50ms/step - accuracy: 0.8347 - loss: 0.3628 - val_accuracy: 0.8667 - val_loss: 0.3072
# Epoch 9/150
#
# Epoch 9: val_accuracy did not improve from 0.86667
# 132/132 - 7s - 50ms/step - accuracy: 0.8434 - loss: 0.3466 - val_accuracy: 0.8621 - val_loss: 0.3135
# Epoch 10/150
#
# Epoch 10: val_accuracy did not improve from 0.86667
# 132/132 - 7s - 49ms/step - accuracy: 0.8506 - loss: 0.3388 - val_accuracy: 0.8561 - val_loss: 0.3205
# Epoch 11/150
#
# Epoch 11: val_accuracy improved from 0.86667 to 0.87121, saving model to best_model.keras
# 132/132 - 8s - 58ms/step - accuracy: 0.8479 - loss: 0.3389 - val_accuracy: 0.8712 - val_loss: 0.2998
# Epoch 12/150
#
# Epoch 12: val_accuracy did not improve from 0.87121
# 132/132 - 7s - 50ms/step - accuracy: 0.8479 - loss: 0.3353 - val_accuracy: 0.8561 - val_loss: 0.3085
# Epoch 13/150
#
# Epoch 13: val_accuracy did not improve from 0.87121
# 132/132 - 7s - 50ms/step - accuracy: 0.8415 - loss: 0.3457 - val_accuracy: 0.8576 - val_loss: 0.3132
# Epoch 14/150
#
# Epoch 14: val_accuracy did not improve from 0.87121
# 132/132 - 7s - 49ms/step - accuracy: 0.8623 - loss: 0.3021 - val_accuracy: 0.8576 - val_loss: 0.3124
# Epoch 15/150
#
# Epoch 15: val_accuracy did not improve from 0.87121
# 132/132 - 6s - 49ms/step - accuracy: 0.8536 - loss: 0.3184 - val_accuracy: 0.8470 - val_loss: 0.3201
# Epoch 16/150
#
# Epoch 16: val_accuracy did not improve from 0.87121
# 132/132 - 7s - 50ms/step - accuracy: 0.8548 - loss: 0.3258 - val_accuracy: 0.8697 - val_loss: 0.3155
# Epoch 17/150
#
# Epoch 17: val_accuracy did not improve from 0.87121
# 132/132 - 7s - 50ms/step - accuracy: 0.8567 - loss: 0.3270 - val_accuracy: 0.8636 - val_loss: 0.3047
# Epoch 18/150
#
# Epoch 18: val_accuracy did not improve from 0.87121
# 132/132 - 7s - 50ms/step - accuracy: 0.8495 - loss: 0.3180 - val_accuracy: 0.8439 - val_loss: 0.3257
# Epoch 19/150
#
# Epoch 19: val_accuracy did not improve from 0.87121
# 132/132 - 7s - 50ms/step - accuracy: 0.8646 - loss: 0.3083 - val_accuracy: 0.8697 - val_loss: 0.3121
# Epoch 20/150
#
# Epoch 20: val_accuracy did not improve from 0.87121
# 132/132 - 7s - 50ms/step - accuracy: 0.8661 - loss: 0.3036 - val_accuracy: 0.8667 - val_loss: 0.3002
# Epoch 21/150
#
# Epoch 21: val_accuracy did not improve from 0.87121
# 132/132 - 7s - 49ms/step - accuracy: 0.8540 - loss: 0.3074 - val_accuracy: 0.8667 - val_loss: 0.2947
# Epoch 22/150
#
# Epoch 22: val_accuracy did not improve from 0.87121
# 132/132 - 7s - 50ms/step - accuracy: 0.8529 - loss: 0.3133 - val_accuracy: 0.8712 - val_loss: 0.3057
# Epoch 23/150
#
# Epoch 23: val_accuracy did not improve from 0.87121
# 132/132 - 7s - 50ms/step - accuracy: 0.8639 - loss: 0.3081 - val_accuracy: 0.8636 - val_loss: 0.3068
# Epoch 24/150
#
# Epoch 24: val_accuracy did not improve from 0.87121
# 132/132 - 7s - 50ms/step - accuracy: 0.8677 - loss: 0.3028 - val_accuracy: 0.8667 - val_loss: 0.3102
# Epoch 25/150
#
# Epoch 25: val_accuracy did not improve from 0.87121
# 132/132 - 7s - 50ms/step - accuracy: 0.8684 - loss: 0.2970 - val_accuracy: 0.8500 - val_loss: 0.3217
# Epoch 26/150
#
# Epoch 26: val_accuracy did not improve from 0.87121
# 132/132 - 7s - 49ms/step - accuracy: 0.8699 - loss: 0.2949 - val_accuracy: 0.8652 - val_loss: 0.3044
# Epoch 27/150
#
# Epoch 27: val_accuracy did not improve from 0.87121
# 132/132 - 7s - 50ms/step - accuracy: 0.8688 - loss: 0.2943 - val_accuracy: 0.8652 - val_loss: 0.3069
# Epoch 28/150
#
# Epoch 28: val_accuracy improved from 0.87121 to 0.87273, saving model to best_model.keras
# 132/132 - 8s - 57ms/step - accuracy: 0.8665 - loss: 0.2936 - val_accuracy: 0.8727 - val_loss: 0.3152
# Epoch 29/150
#
# Epoch 29: val_accuracy did not improve from 0.87273
# 132/132 - 7s - 50ms/step - accuracy: 0.8707 - loss: 0.2944 - val_accuracy: 0.8712 - val_loss: 0.3167
# Epoch 30/150
#
# Epoch 30: val_accuracy did not improve from 0.87273
# 132/132 - 7s - 50ms/step - accuracy: 0.8654 - loss: 0.2826 - val_accuracy: 0.8636 - val_loss: 0.3113
# Epoch 31/150
#
# Epoch 31: val_accuracy did not improve from 0.87273
# 132/132 - 6s - 49ms/step - accuracy: 0.8635 - loss: 0.2901 - val_accuracy: 0.8621 - val_loss: 0.3174
# Epoch 32/150
#
# Epoch 32: val_accuracy did not improve from 0.87273
# 132/132 - 7s - 50ms/step - accuracy: 0.8703 - loss: 0.2828 - val_accuracy: 0.8470 - val_loss: 0.3184
# Epoch 33/150
#
# Epoch 33: val_accuracy did not improve from 0.87273
# 132/132 - 6s - 49ms/step - accuracy: 0.8654 - loss: 0.2930 - val_accuracy: 0.8712 - val_loss: 0.3210
# Epoch 34/150
#
# Epoch 34: val_accuracy did not improve from 0.87273
# 132/132 - 7s - 50ms/step - accuracy: 0.8745 - loss: 0.2693 - val_accuracy: 0.8667 - val_loss: 0.3302
# Epoch 35/150
#
# Epoch 35: val_accuracy improved from 0.87273 to 0.87576, saving model to best_model.keras
# 132/132 - 8s - 58ms/step - accuracy: 0.8760 - loss: 0.2814 - val_accuracy: 0.8758 - val_loss: 0.3031
# Epoch 36/150
#
# Epoch 36: val_accuracy did not improve from 0.87576
# 132/132 - 7s - 50ms/step - accuracy: 0.8608 - loss: 0.3040 - val_accuracy: 0.8621 - val_loss: 0.3053
# Epoch 37/150
#
# Epoch 37: val_accuracy did not improve from 0.87576
# 132/132 - 7s - 49ms/step - accuracy: 0.8722 - loss: 0.2853 - val_accuracy: 0.8712 - val_loss: 0.3036
# Epoch 38/150
#
# Epoch 38: val_accuracy did not improve from 0.87576
# 132/132 - 7s - 50ms/step - accuracy: 0.8722 - loss: 0.2891 - val_accuracy: 0.8576 - val_loss: 0.2994
# Epoch 39/150
#
# Epoch 39: val_accuracy did not improve from 0.87576
# 132/132 - 7s - 50ms/step - accuracy: 0.8771 - loss: 0.2833 - val_accuracy: 0.8667 - val_loss: 0.3180
# Epoch 40/150
#
# Epoch 40: val_accuracy did not improve from 0.87576
# 132/132 - 7s - 51ms/step - accuracy: 0.8733 - loss: 0.2954 - val_accuracy: 0.8652 - val_loss: 0.3040
# Epoch 41/150
#
# Epoch 41: val_accuracy did not improve from 0.87576
# 132/132 - 7s - 50ms/step - accuracy: 0.8805 - loss: 0.2687 - val_accuracy: 0.8758 - val_loss: 0.2995
# Epoch 42/150
#
# Epoch 42: val_accuracy improved from 0.87576 to 0.88030, saving model to best_model.keras
# 132/132 - 8s - 58ms/step - accuracy: 0.8790 - loss: 0.2628 - val_accuracy: 0.8803 - val_loss: 0.3065
# Epoch 43/150
#
# Epoch 43: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.8790 - loss: 0.2759 - val_accuracy: 0.8712 - val_loss: 0.3292
# Epoch 44/150
#
# Epoch 44: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.8836 - loss: 0.2694 - val_accuracy: 0.8788 - val_loss: 0.3125
# Epoch 45/150
#
# Epoch 45: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.8851 - loss: 0.2694 - val_accuracy: 0.8545 - val_loss: 0.3206
# Epoch 46/150
#
# Epoch 46: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.8790 - loss: 0.2706 - val_accuracy: 0.8682 - val_loss: 0.3100
# Epoch 47/150
#
# Epoch 47: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 49ms/step - accuracy: 0.8764 - loss: 0.2688 - val_accuracy: 0.8712 - val_loss: 0.3116
# Epoch 48/150
#
# Epoch 48: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.8904 - loss: 0.2581 - val_accuracy: 0.8742 - val_loss: 0.3075
# Epoch 49/150
#
# Epoch 49: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.8855 - loss: 0.2530 - val_accuracy: 0.8742 - val_loss: 0.3099
# Epoch 50/150
#
# Epoch 50: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.8802 - loss: 0.2632 - val_accuracy: 0.8742 - val_loss: 0.3182
# Epoch 51/150
#
# Epoch 51: val_accuracy did not improve from 0.88030
# 132/132 - 6s - 49ms/step - accuracy: 0.8840 - loss: 0.2585 - val_accuracy: 0.8742 - val_loss: 0.3093
# Epoch 52/150
#
# Epoch 52: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 49ms/step - accuracy: 0.8889 - loss: 0.2533 - val_accuracy: 0.8652 - val_loss: 0.3130
# Epoch 53/150
#
# Epoch 53: val_accuracy did not improve from 0.88030
# 132/132 - 6s - 49ms/step - accuracy: 0.8787 - loss: 0.2687 - val_accuracy: 0.8697 - val_loss: 0.3117
# Epoch 54/150
#
# Epoch 54: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.8889 - loss: 0.2591 - val_accuracy: 0.8576 - val_loss: 0.3325
# Epoch 55/150
#
# Epoch 55: val_accuracy did not improve from 0.88030
# 132/132 - 6s - 49ms/step - accuracy: 0.8832 - loss: 0.2583 - val_accuracy: 0.8682 - val_loss: 0.3107
# Epoch 56/150
#
# Epoch 56: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.8828 - loss: 0.2586 - val_accuracy: 0.8652 - val_loss: 0.3074
# Epoch 57/150
#
# Epoch 57: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.8790 - loss: 0.2721 - val_accuracy: 0.8758 - val_loss: 0.3013
# Epoch 58/150
#
# Epoch 58: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.8870 - loss: 0.2541 - val_accuracy: 0.8682 - val_loss: 0.3298
# Epoch 59/150
#
# Epoch 59: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.8870 - loss: 0.2598 - val_accuracy: 0.8697 - val_loss: 0.3144
# Epoch 60/150
#
# Epoch 60: val_accuracy did not improve from 0.88030
# 132/132 - 6s - 49ms/step - accuracy: 0.8957 - loss: 0.2411 - val_accuracy: 0.8485 - val_loss: 0.3208
# Epoch 61/150
#
# Epoch 61: val_accuracy did not improve from 0.88030
# 132/132 - 6s - 49ms/step - accuracy: 0.8874 - loss: 0.2587 - val_accuracy: 0.8697 - val_loss: 0.3115
# Epoch 62/150
#
# Epoch 62: val_accuracy did not improve from 0.88030
# 132/132 - 6s - 49ms/step - accuracy: 0.8870 - loss: 0.2516 - val_accuracy: 0.8561 - val_loss: 0.3164
# Epoch 63/150
#
# Epoch 63: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.8934 - loss: 0.2590 - val_accuracy: 0.8621 - val_loss: 0.3163
# Epoch 64/150
#
# Epoch 64: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 49ms/step - accuracy: 0.8942 - loss: 0.2416 - val_accuracy: 0.8667 - val_loss: 0.3136
# Epoch 65/150
#
# Epoch 65: val_accuracy did not improve from 0.88030
# 132/132 - 6s - 49ms/step - accuracy: 0.8934 - loss: 0.2478 - val_accuracy: 0.8773 - val_loss: 0.3083
# Epoch 66/150
#
# Epoch 66: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.8843 - loss: 0.2651 - val_accuracy: 0.8561 - val_loss: 0.3200
# Epoch 67/150
#
# Epoch 67: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.8942 - loss: 0.2358 - val_accuracy: 0.8652 - val_loss: 0.3137
# Epoch 68/150
#
# Epoch 68: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.8915 - loss: 0.2439 - val_accuracy: 0.8652 - val_loss: 0.3209
# Epoch 69/150
#
# Epoch 69: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.8999 - loss: 0.2241 - val_accuracy: 0.8636 - val_loss: 0.3235
# Epoch 70/150
#
# Epoch 70: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.8881 - loss: 0.2530 - val_accuracy: 0.8606 - val_loss: 0.3201
# Epoch 71/150
#
# Epoch 71: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 49ms/step - accuracy: 0.8999 - loss: 0.2315 - val_accuracy: 0.8682 - val_loss: 0.3130
# Epoch 72/150
#
# Epoch 72: val_accuracy did not improve from 0.88030
# 132/132 - 6s - 49ms/step - accuracy: 0.9041 - loss: 0.2312 - val_accuracy: 0.8667 - val_loss: 0.3141
# Epoch 73/150
#
# Epoch 73: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.8950 - loss: 0.2430 - val_accuracy: 0.8500 - val_loss: 0.3353
# Epoch 74/150
#
# Epoch 74: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 49ms/step - accuracy: 0.8976 - loss: 0.2476 - val_accuracy: 0.8636 - val_loss: 0.3186
# Epoch 75/150
#
# Epoch 75: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 49ms/step - accuracy: 0.8946 - loss: 0.2379 - val_accuracy: 0.8682 - val_loss: 0.3212
# Epoch 76/150
#
# Epoch 76: val_accuracy did not improve from 0.88030
# 132/132 - 6s - 49ms/step - accuracy: 0.8927 - loss: 0.2522 - val_accuracy: 0.8682 - val_loss: 0.3154
# Epoch 77/150
#
# Epoch 77: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.8965 - loss: 0.2453 - val_accuracy: 0.8636 - val_loss: 0.3125
# Epoch 78/150
#
# Epoch 78: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.8942 - loss: 0.2286 - val_accuracy: 0.8576 - val_loss: 0.3316
# Epoch 79/150
#
# Epoch 79: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.8961 - loss: 0.2302 - val_accuracy: 0.8727 - val_loss: 0.3277
# Epoch 80/150
#
# Epoch 80: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.8995 - loss: 0.2339 - val_accuracy: 0.8606 - val_loss: 0.3204
# Epoch 81/150
#
# Epoch 81: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.9044 - loss: 0.2330 - val_accuracy: 0.8667 - val_loss: 0.3217
# Epoch 82/150
#
# Epoch 82: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.8923 - loss: 0.2434 - val_accuracy: 0.8682 - val_loss: 0.3183
# Epoch 83/150
#
# Epoch 83: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.8961 - loss: 0.2341 - val_accuracy: 0.8682 - val_loss: 0.3282
# Epoch 84/150
#
# Epoch 84: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 49ms/step - accuracy: 0.9075 - loss: 0.2224 - val_accuracy: 0.8758 - val_loss: 0.3183
# Epoch 85/150
#
# Epoch 85: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.9014 - loss: 0.2246 - val_accuracy: 0.8621 - val_loss: 0.3429
# Epoch 86/150
#
# Epoch 86: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 49ms/step - accuracy: 0.9048 - loss: 0.2198 - val_accuracy: 0.8485 - val_loss: 0.3402
# Epoch 87/150
#
# Epoch 87: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.9014 - loss: 0.2202 - val_accuracy: 0.8455 - val_loss: 0.3300
# Epoch 88/150
#
# Epoch 88: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.8999 - loss: 0.2169 - val_accuracy: 0.8606 - val_loss: 0.3337
# Epoch 89/150
#
# Epoch 89: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.8984 - loss: 0.2347 - val_accuracy: 0.8667 - val_loss: 0.3308
# Epoch 90/150
#
# Epoch 90: val_accuracy did not improve from 0.88030
# 132/132 - 6s - 49ms/step - accuracy: 0.9063 - loss: 0.2140 - val_accuracy: 0.8636 - val_loss: 0.3318
# Epoch 91/150
#
# Epoch 91: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 49ms/step - accuracy: 0.9041 - loss: 0.2124 - val_accuracy: 0.8621 - val_loss: 0.3334
# Epoch 92/150
#
# Epoch 92: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.9048 - loss: 0.2247 - val_accuracy: 0.8470 - val_loss: 0.3206
# Epoch 93/150
#
# Epoch 93: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.9078 - loss: 0.2240 - val_accuracy: 0.8667 - val_loss: 0.3189
# Epoch 94/150
#
# Epoch 94: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 49ms/step - accuracy: 0.9037 - loss: 0.2239 - val_accuracy: 0.8652 - val_loss: 0.3255
# Epoch 95/150
#
# Epoch 95: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 49ms/step - accuracy: 0.8976 - loss: 0.2259 - val_accuracy: 0.8636 - val_loss: 0.3253
# Epoch 96/150
#
# Epoch 96: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 49ms/step - accuracy: 0.8969 - loss: 0.2279 - val_accuracy: 0.8682 - val_loss: 0.3320
# Epoch 97/150
#
# Epoch 97: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.9048 - loss: 0.2357 - val_accuracy: 0.8697 - val_loss: 0.3275
# Epoch 98/150
#
# Epoch 98: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 51ms/step - accuracy: 0.9075 - loss: 0.2191 - val_accuracy: 0.8606 - val_loss: 0.3321
# Epoch 99/150
#
# Epoch 99: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 49ms/step - accuracy: 0.9048 - loss: 0.2290 - val_accuracy: 0.8576 - val_loss: 0.3278
# Epoch 100/150
#
# Epoch 100: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.9056 - loss: 0.2166 - val_accuracy: 0.8697 - val_loss: 0.3303
# Epoch 101/150
#
# Epoch 101: val_accuracy did not improve from 0.88030
# 132/132 - 10s - 78ms/step - accuracy: 0.9181 - loss: 0.2100 - val_accuracy: 0.8591 - val_loss: 0.3346
# Epoch 102/150
#
# Epoch 102: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 51ms/step - accuracy: 0.9113 - loss: 0.2097 - val_accuracy: 0.8621 - val_loss: 0.3353
# Epoch 103/150
#
# Epoch 103: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.9010 - loss: 0.2404 - val_accuracy: 0.8591 - val_loss: 0.3289
# Epoch 104/150
#
# Epoch 104: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.9003 - loss: 0.2188 - val_accuracy: 0.8591 - val_loss: 0.3326
# Epoch 105/150
#
# Epoch 105: val_accuracy did not improve from 0.88030
# 132/132 - 6s - 49ms/step - accuracy: 0.9101 - loss: 0.2156 - val_accuracy: 0.8697 - val_loss: 0.3345
# Epoch 106/150
#
# Epoch 106: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.9124 - loss: 0.2094 - val_accuracy: 0.8667 - val_loss: 0.3429
# Epoch 107/150
#
# Epoch 107: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.9071 - loss: 0.2182 - val_accuracy: 0.8545 - val_loss: 0.3406
# Epoch 108/150
#
# Epoch 108: val_accuracy did not improve from 0.88030
# 132/132 - 6s - 49ms/step - accuracy: 0.9082 - loss: 0.2090 - val_accuracy: 0.8591 - val_loss: 0.3294
# Epoch 109/150
#
# Epoch 109: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 49ms/step - accuracy: 0.9097 - loss: 0.2173 - val_accuracy: 0.8576 - val_loss: 0.3278
# Epoch 110/150
#
# Epoch 110: val_accuracy did not improve from 0.88030
# 132/132 - 6s - 49ms/step - accuracy: 0.9071 - loss: 0.2203 - val_accuracy: 0.8621 - val_loss: 0.3357
# Epoch 111/150
#
# Epoch 111: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.9094 - loss: 0.2114 - val_accuracy: 0.8545 - val_loss: 0.3378
# Epoch 112/150
#
# Epoch 112: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.9154 - loss: 0.2117 - val_accuracy: 0.8606 - val_loss: 0.3535
# Epoch 113/150
#
# Epoch 113: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.9044 - loss: 0.2322 - val_accuracy: 0.8515 - val_loss: 0.3384
# Epoch 114/150
#
# Epoch 114: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.8999 - loss: 0.2333 - val_accuracy: 0.8606 - val_loss: 0.3217
# Epoch 115/150
#
# Epoch 115: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.9151 - loss: 0.1996 - val_accuracy: 0.8682 - val_loss: 0.3423
# Epoch 116/150
#
# Epoch 116: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.9158 - loss: 0.2067 - val_accuracy: 0.8652 - val_loss: 0.3323
# Epoch 117/150
#
# Epoch 117: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.9124 - loss: 0.2081 - val_accuracy: 0.8576 - val_loss: 0.3377
# Epoch 118/150
#
# Epoch 118: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.9158 - loss: 0.1978 - val_accuracy: 0.8561 - val_loss: 0.3425
# Epoch 119/150
#
# Epoch 119: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 49ms/step - accuracy: 0.9128 - loss: 0.2128 - val_accuracy: 0.8682 - val_loss: 0.3373
# Epoch 120/150
#
# Epoch 120: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 49ms/step - accuracy: 0.9188 - loss: 0.2004 - val_accuracy: 0.8439 - val_loss: 0.3399
# Epoch 121/150
#
# Epoch 121: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.9170 - loss: 0.2045 - val_accuracy: 0.8636 - val_loss: 0.3369
# Epoch 122/150
#
# Epoch 122: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.9113 - loss: 0.2106 - val_accuracy: 0.8500 - val_loss: 0.3447
# Epoch 123/150
#
# Epoch 123: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.9075 - loss: 0.2122 - val_accuracy: 0.8561 - val_loss: 0.3327
# Epoch 124/150
#
# Epoch 124: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 49ms/step - accuracy: 0.9006 - loss: 0.2281 - val_accuracy: 0.8606 - val_loss: 0.3264
# Epoch 125/150
#
# Epoch 125: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.9238 - loss: 0.1901 - val_accuracy: 0.8455 - val_loss: 0.3603
# Epoch 126/150
#
# Epoch 126: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.9135 - loss: 0.1981 - val_accuracy: 0.8667 - val_loss: 0.3506
# Epoch 127/150
#
# Epoch 127: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 49ms/step - accuracy: 0.9041 - loss: 0.2123 - val_accuracy: 0.8515 - val_loss: 0.3574
# Epoch 128/150
#
# Epoch 128: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.9170 - loss: 0.1961 - val_accuracy: 0.8606 - val_loss: 0.3436
# Epoch 129/150
#
# Epoch 129: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 49ms/step - accuracy: 0.9264 - loss: 0.1817 - val_accuracy: 0.8530 - val_loss: 0.3485
# Epoch 130/150
#
# Epoch 130: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.9204 - loss: 0.2013 - val_accuracy: 0.8576 - val_loss: 0.3442
# Epoch 131/150
#
# Epoch 131: val_accuracy did not improve from 0.88030
# 132/132 - 10s - 77ms/step - accuracy: 0.9170 - loss: 0.1830 - val_accuracy: 0.8652 - val_loss: 0.3527
# Epoch 132/150
#
# Epoch 132: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 49ms/step - accuracy: 0.9196 - loss: 0.1990 - val_accuracy: 0.8485 - val_loss: 0.3652
# Epoch 133/150
#
# Epoch 133: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.9078 - loss: 0.2128 - val_accuracy: 0.8576 - val_loss: 0.3410
# Epoch 134/150
#
# Epoch 134: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.9226 - loss: 0.1895 - val_accuracy: 0.8636 - val_loss: 0.3485
# Epoch 135/150
#
# Epoch 135: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.9101 - loss: 0.2146 - val_accuracy: 0.8591 - val_loss: 0.3399
# Epoch 136/150
#
# Epoch 136: val_accuracy did not improve from 0.88030
# 132/132 - 6s - 49ms/step - accuracy: 0.9264 - loss: 0.1786 - val_accuracy: 0.8652 - val_loss: 0.3495
# Epoch 137/150
#
# Epoch 137: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 49ms/step - accuracy: 0.9166 - loss: 0.1991 - val_accuracy: 0.8591 - val_loss: 0.3585
# Epoch 138/150
#
# Epoch 138: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.9166 - loss: 0.1972 - val_accuracy: 0.8485 - val_loss: 0.3503
# Epoch 139/150
#
# Epoch 139: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.9196 - loss: 0.1858 - val_accuracy: 0.8530 - val_loss: 0.3790
# Epoch 140/150
#
# Epoch 140: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.9139 - loss: 0.2021 - val_accuracy: 0.8500 - val_loss: 0.3601
# Epoch 141/150
#
# Epoch 141: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.9177 - loss: 0.1990 - val_accuracy: 0.8576 - val_loss: 0.3671
# Epoch 142/150
#
# Epoch 142: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 49ms/step - accuracy: 0.9192 - loss: 0.1975 - val_accuracy: 0.8470 - val_loss: 0.3551
# Epoch 143/150
#
# Epoch 143: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 49ms/step - accuracy: 0.9242 - loss: 0.1954 - val_accuracy: 0.8500 - val_loss: 0.3569
# Epoch 144/150
#
# Epoch 144: val_accuracy did not improve from 0.88030
# 132/132 - 10s - 78ms/step - accuracy: 0.9185 - loss: 0.1986 - val_accuracy: 0.8485 - val_loss: 0.3550
# Epoch 145/150
#
# Epoch 145: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 49ms/step - accuracy: 0.9287 - loss: 0.1805 - val_accuracy: 0.8470 - val_loss: 0.3522
# Epoch 146/150
#
# Epoch 146: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.9116 - loss: 0.2065 - val_accuracy: 0.8379 - val_loss: 0.3807
# Epoch 147/150
#
# Epoch 147: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.9124 - loss: 0.1993 - val_accuracy: 0.8500 - val_loss: 0.3559
# Epoch 148/150
#
# Epoch 148: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.9139 - loss: 0.2099 - val_accuracy: 0.8500 - val_loss: 0.3551
# Epoch 149/150
#
# Epoch 149: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.9268 - loss: 0.1747 - val_accuracy: 0.8652 - val_loss: 0.3717
# Epoch 150/150
#
# Epoch 150: val_accuracy did not improve from 0.88030
# 132/132 - 7s - 50ms/step - accuracy: 0.9196 - loss: 0.1969 - val_accuracy: 0.8515 - val_loss: 0.3606

# %% [markdown]
# <div class="alert alert-block alert-secondary" style="font-size:14px; font-family:verdana; background-color:#d3d3d3; color:#555555;">
#     📌 The model reached a validation accuracy of 88%, which is higher than the initial test result. Better results can be achieved with hyperparameter tuning.
# </div>

# %% [markdown]
# ## 8. Training Results

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(train_accuracy, label='Train Accuracy')
plt.plot(val_accuracy, label='Validation Accuracy')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='lower right')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(train_loss, label='Train Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')

# Show the plots
plt.tight_layout()
plt.show()
